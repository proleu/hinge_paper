# %%
import pandas as pd

num_plates = 1

sheet_dfs = []
excel_file = pd.ExcelFile('/home/broerman/ln/my_expdata/Plate Reader/DABs/20221108_FRET_CS221_DAB21_kinetics.xlsx')
binding_df = pd.read_excel(excel_file, sheet_name=f"Plate 1 - Sheet1", skiprows=4, nrows=901, usecols="B:CU")

from IPython.display import display
with pd.option_context(
    'display.max_columns', None,
    # 'display.max_rows', None,
):
    display(binding_df)
# Out:
#          Time  T° 520,665  A1    A2  A3  A4  A5  A6  A7  A8  A9  A10  A11  \
# 0    00:00:00        25.4 NaN  2809 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN
# 1    00:00:06        25.4 NaN  2755 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN
# 2    00:00:12        25.4 NaN  2957 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN
# 3    00:00:18        25.4 NaN  2857 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN
# 4    00:00:24        25.4 NaN  2718 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN
# ..        ...         ...  ..   ...  ..  ..  ..  ..  ..  ..  ..  ...  ...
# 896  01:29:36        25.3 NaN  3838 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN
# 897  01:29:42        25.3 NaN  4117 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN
# 898  01:29:48        25.3 NaN  4044 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN
# 899  01:29:54        25.3 NaN  3990 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN
# 900  01:30:00        25.3 NaN  4096 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN
#
#      A12  B1    B2  B3  B4  B5  B6  B7  B8  B9  B10  B11  B12  C1    C2  C3  \
# 0    NaN NaN  2777 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  2883 NaN
# 1    NaN NaN  2792 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  2833 NaN
# 2    NaN NaN  3012 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  2841 NaN
# 3    NaN NaN  2868 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3097 NaN
# 4    NaN NaN  2845 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  2956 NaN
# ..   ...  ..   ...  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ..   ...  ..
# 896  NaN NaN  4044 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4041 NaN
# 897  NaN NaN  4082 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3982 NaN
# 898  NaN NaN  4015 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4252 NaN
# 899  NaN NaN  4058 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4184 NaN
# 900  NaN NaN  4271 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4202 NaN
#
#      C4  C5  C6  C7  C8  C9  C10  C11  C12  D1    D2  D3  D4  D5  D6  D7  D8  \
# 0   NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  2982 NaN NaN NaN NaN NaN NaN
# 1   NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  2905 NaN NaN NaN NaN NaN NaN
# 2   NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  2856 NaN NaN NaN NaN NaN NaN
# 3   NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  2931 NaN NaN NaN NaN NaN NaN
# 4   NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  2878 NaN NaN NaN NaN NaN NaN
# ..   ..  ..  ..  ..  ..  ..  ...  ...  ...  ..   ...  ..  ..  ..  ..  ..  ..
# 896 NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4198 NaN NaN NaN NaN NaN NaN
# 897 NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3892 NaN NaN NaN NaN NaN NaN
# 898 NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4090 NaN NaN NaN NaN NaN NaN
# 899 NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4090 NaN NaN NaN NaN NaN NaN
# 900 NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4166 NaN NaN NaN NaN NaN NaN
#
#      D9  D10  D11  D12  E1    E2  E3  E4  E5  E6  E7  E8  E9  E10  E11  E12  \
# 0   NaN  NaN  NaN  NaN NaN  2959 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN
# 1   NaN  NaN  NaN  NaN NaN  3021 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN
# 2   NaN  NaN  NaN  NaN NaN  3059 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN
# 3   NaN  NaN  NaN  NaN NaN  3202 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN NaN  3195 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN
# ..   ..  ...  ...  ...  ..   ...  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...
# 896 NaN  NaN  NaN  NaN NaN  4301 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN
# 897 NaN  NaN  NaN  NaN NaN  4241 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN
# 898 NaN  NaN  NaN  NaN NaN  4309 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN
# 899 NaN  NaN  NaN  NaN NaN  4165 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN
# 900 NaN  NaN  NaN  NaN NaN  4329 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN
#
#      F1    F2  F3  F4  F5  F6  F7  F8  F9  F10  F11  F12  G1    G2  G3  G4  \
# 0   NaN  2939 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  2984 NaN NaN
# 1   NaN  2968 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3234 NaN NaN
# 2   NaN  2989 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3170 NaN NaN
# 3   NaN  2838 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3146 NaN NaN
# 4   NaN  3051 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3344 NaN NaN
# ..   ..   ...  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ..   ...  ..  ..
# 896 NaN  3976 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4074 NaN NaN
# 897 NaN  3839 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4149 NaN NaN
# 898 NaN  4089 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4015 NaN NaN
# 899 NaN  3848 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4043 NaN NaN
# 900 NaN  3858 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4150 NaN NaN
#
#      G5  G6  G7  G8  G9  G10  G11  G12  H1    H2  H3  H4  H5  H6  H7  H8  H9  \
# 0   NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3170 NaN NaN NaN NaN NaN NaN NaN
# 1   NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3188 NaN NaN NaN NaN NaN NaN NaN
# 2   NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3218 NaN NaN NaN NaN NaN NaN NaN
# 3   NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3096 NaN NaN NaN NaN NaN NaN NaN
# 4   NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  3300 NaN NaN NaN NaN NaN NaN NaN
# ..   ..  ..  ..  ..  ..  ...  ...  ...  ..   ...  ..  ..  ..  ..  ..  ..  ..
# 896 NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4357 NaN NaN NaN NaN NaN NaN NaN
# 897 NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4234 NaN NaN NaN NaN NaN NaN NaN
# 898 NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4427 NaN NaN NaN NaN NaN NaN NaN
# 899 NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4189 NaN NaN NaN NaN NaN NaN NaN
# 900 NaN NaN NaN NaN NaN  NaN  NaN  NaN NaN  4331 NaN NaN NaN NaN NaN NaN NaN
#
#      H10  H11  H12
# 0    NaN  NaN  NaN
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# ..   ...  ...  ...
# 896  NaN  NaN  NaN
# 897  NaN  NaN  NaN
# 898  NaN  NaN  NaN
# 899  NaN  NaN  NaN
# 900  NaN  NaN  NaN
#
# [901 rows x 98 columns]

# %%
start_conc = 400 # nM
const_conc = 5 # nM

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set(
    context="notebook",
    style="ticks",  # make the background white with black lines
    palette="colorblind",  # a color palette that is colorblind friendly!
)

from scipy.optimize import curve_fit
def order_1_curve(t, a, k): # units of luminescence, t = time (s), a = saturation signal (luminescence), k = rate constant (1/s)
    return a * (1 - np.exp(-k * t))

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,6))

t_data = pd.to_timedelta(binding_df.loc[:, "Time"].astype(str)).dt.total_seconds()

binding_data = binding_df.iloc[:, [i*12+3 for i in range(8)]]
# binding_data = np.where(binding_data == "OVRFLW", 6000000, binding_data)
for i, color in zip(range(8), [sns.color_palette("flare", as_cmap=True)(x) for x in np.linspace(0, 1, 8)]):
    s0 = start_conc*(i+1)/8
    sns.lineplot(x=t_data, y=binding_data.iloc[:, i], label=f'{s0/1000000000:.00e} M', zorder=-1, ax=ax, color=color)#, legend=None)

# ax.set_xlim(0.00000003, 0.00013)
# ax.set_ylim(0, 1)
ax.set_xlabel(f'Time (s)')
ax.set_ylabel('Ex 520nm / Em 665nm (a.u.)')
# ax.set_title(f'{combo_data[0]}\n[{combo_data[2]}] = 100pm\nKd = {Kd:.01f}nM')
# ax.text(0.05, 0.95, f'Kd = {np.mean(Kds)/1000000000:.00e} M\n[{combo_data[2]}] = 1e-10 M', horizontalalignment='left', verticalalignment='top', transform=ax.transAxes)
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12))
ax.legend()

fig.tight_layout()
fig.patch.set_alpha(0)
fig.savefig("CS221_DAB21_kinetics.png", dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set(
    context="notebook",
    style="ticks",  # make the background white with black lines
    palette="colorblind",  # a color palette that is colorblind friendly!
)

from scipy.optimize import curve_fit
def order_1_curve(t, a, k, start): # units of luminescence, t = time (s), a = saturation signal, k = rate constant (1/s)
    return a * (1 - np.exp(-k * t)) + start

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,6))

t_data = pd.to_timedelta(binding_df.loc[:, "Time"].astype(str)).dt.total_seconds() + 30

fits = {}

binding_data = binding_df.iloc[:, [i*12+3 for i in range(8)]]
# binding_data = np.where(binding_data == "OVRFLW", 6000000, binding_data)
for i, color in zip(range(8), [sns.color_palette("flare", as_cmap=True)(x) for x in np.linspace(0, 1, 8)]):
    s0 = start_conc*(i+1)/8
    binding_col = binding_data.iloc[:, i]
    # max_i = np.argmax(binding_col)
    # binding_fit = binding_col[:max_i]
    # t_fit = t_data[:max_i]
    sns.scatterplot(x=t_data, y=binding_col, label=f'{s0/1000000000:.00e} M', zorder=-1, ax=ax, color=color)
    try:
        (sat, k_app, start), pcov = curve_fit(order_1_curve, t_data, binding_col, bounds=((0,0,0),(np.inf,0.1,np.inf)))
        sns.lineplot(x=t_data, y=order_1_curve(t_data, sat, k_app, start), color=color, ax=ax)
        fits[s0] = (sat, k_app, start)
        print(f'{s0/1000000000:.01e} M: {sat:.02e}, {k_app:.02e}, {start:.02e}')
    except RuntimeError:
        print(f"fit {i} failed")
ax.set_xlabel(f'Time (s)')
ax.set_ylabel('Ex 520nm / Em 665nm (a.u.)')
ax.legend()

fig.tight_layout()
fig.patch.set_alpha(0)
fig.savefig("CS221_DAB21_kinetics_fit.png", dpi=300)
# Out:
# 5.0e-08 M: 1.34e+03, 3.28e-04, 2.86e+03
# 1.0e-07 M: 1.28e+03, 4.20e-04, 2.91e+03
# 1.5e-07 M: 1.27e+03, 7.73e-04, 2.86e+03
# 2.0e-07 M: 1.21e+03, 1.17e-03, 2.89e+03
# 2.5e-07 M: 1.25e+03, 2.10e-03, 3.00e+03
# 3.0e-07 M: 1.12e+03, 3.15e-03, 2.85e+03
# 3.5e-07 M: 1.09e+03, 3.63e-03, 3.05e+03
# 4.0e-07 M: 1.35e+03, 5.71e-03, 2.95e+03

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set(
    context="notebook",
    style="ticks",  # make the background white with black lines
    palette="colorblind",  # a color palette that is colorblind friendly!
)

from scipy.optimize import curve_fit
def order_1_curve(t, a, k, start): # units of luminescence, t = time (s), a = saturation signal, k = rate constant (1/s)
    return a * (1 - np.exp(-k * t)) + start

fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(16,8))

t_data = pd.to_timedelta(binding_df.loc[:, "Time"].astype(str)).dt.total_seconds() + 30

fits = {}

binding_data = binding_df.iloc[:, [i*12+3 for i in range(8)]]
# binding_data = np.where(binding_data == "OVRFLW", 6000000, binding_data)
for i, ax in zip(range(8), axs.flatten()):
    s0 = start_conc*(i+1)/8
    binding_col = binding_data.iloc[:, i]
    # max_i = np.argmax(binding_col)
    # binding_fit = binding_col[:max_i]
    # t_fit = t_data[:max_i]
    sns.scatterplot(x=t_data, y=binding_col, zorder=-1, ax=ax)
    try:
        (sat, k_app, start), pcov = curve_fit(order_1_curve, t_data, binding_col, bounds=((0,0,0),(np.inf,0.1,np.inf)))
        sns.lineplot(x=t_data, y=order_1_curve(t_data, sat, k_app, start), ax=ax, color="C1")
        fits[s0] = (sat, k_app, start)
        print(f'{s0/1000000000:.01e} M: {sat:.02e}, {k_app:.02e}, {start:.02e}')
    except RuntimeError:
        print(f"fit {i} failed")
    ax.set_xlabel(f'Time (s)')
    ax.set_ylabel('Ex 520nm / Em 665nm (a.u.)')
    ax.text(0.95, 0.08, f'[DAB21] = {s0/1000000000:.01e} M\nk_app = {k_app:.01e} 1/s', horizontalalignment='right', verticalalignment='center', transform=ax.transAxes)

fig.tight_layout()
fig.patch.set_alpha(0)
fig.savefig("CS221_DAB21_kinetics_fit_separate.png", dpi=300)
# Out:
# 5.0e-08 M: 1.34e+03, 3.28e-04, 2.86e+03
# 1.0e-07 M: 1.28e+03, 4.20e-04, 2.91e+03
# 1.5e-07 M: 1.27e+03, 7.73e-04, 2.86e+03
# 2.0e-07 M: 1.21e+03, 1.17e-03, 2.89e+03
# 2.5e-07 M: 1.25e+03, 2.10e-03, 3.00e+03
# 3.0e-07 M: 1.12e+03, 3.15e-03, 2.85e+03
# 3.5e-07 M: 1.09e+03, 3.63e-03, 3.05e+03
# 4.0e-07 M: 1.35e+03, 5.71e-03, 2.95e+03

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))

sns.scatterplot(x=[c/1000000000 for c in fits.keys()], y=[fit[1] for fit in fits.values()], ax=ax)

ax.set_xlabel(f'[DAB21] (M)')
ax.set_ylabel('k_app (1/s)')

fig.tight_layout()
fig.patch.set_alpha(0)
fig.savefig("CS221_DAB21_kinetics_kapp_conc.png", dpi=300)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,6))

def line(c, kon, koff): # units of luminescence, t = time (s), a = saturation signal (luminescence), k = rate constant (1/s)
    return kon*c+koff

concs = np.array([c/1000000000 for c in list(fits.keys())])
ks = np.array([fit[1] for fit in list(fits.values())])

sns.scatterplot(x=concs, y=ks, ax=ax)
try:
    (kon, koff), pcov = curve_fit(line, concs[3:], ks[3:])
    sns.lineplot(x=concs, y=line(concs, kon, koff), color='k', zorder=-1, ax=ax)
    ax.text(0.05, 0.95, f'k_on = {kon:.00e} 1/M-s', horizontalalignment='left', verticalalignment='top', transform=ax.transAxes)
    print(kon)
except RuntimeError:
    print(f"fit failed")

ax.set_xlabel(f'[DAB21] (M)')
ax.set_ylabel('k_app (1/s)')

fig.tight_layout()
fig.patch.set_alpha(0)
fig.savefig("CS221_DAB21_kinetics_kapp_conc_fit.png", dpi=300)
# Out:
# 21220.800870970827
