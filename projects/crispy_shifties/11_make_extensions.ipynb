# %% [markdown]
# # Make extended versions for FRET, etc.

# %% [markdown]
# ### Imports

# %%
# %load_ext lab_black
# Python standard library
from glob import glob
import os
import socket
import sys

# 3rd party library imports
import dask
import matplotlib.pyplot as plt
import pandas as pd
import pyrosetta
import numpy as np
import scipy
import seaborn as sns
from tqdm.auto import tqdm  # jupyter compatible progress bar

tqdm.pandas()  # link tqdm to pandas
# Notebook magic
# save plots in the notebook
# %matplotlib inline
# reloads modules automatically before executing cells
# %load_ext autoreload
# %autoreload 2
print(f"running in directory: {os.getcwd()}")  # where are we?
print(f"running on node: {socket.gethostname()}")  # what node are we on?
# Out:
# running in directory: /mnt/projects/crispy_shifty/projects/crispy_shifties
# running on node: gpu44

# %% [markdown]
# ### Set working directory to the root of the crispy_shifty repo

# %%
os.chdir("/projects/crispy_shifty")

# %% [markdown]
# ### Start on some from Flo

# %%
hinge = "/mnt/home/flop/switch/5thround/extend/cs221_Y_n1c1.pdb"
basename = "cs_221AB_n1c1"
num_repeats_extended = 1

sys.path.insert(0, "/projects/crispy_shifty")
from crispy_shifty.protocols.cleaning import design_after_repeat_propagation

simulation_name = "11_make_extensions"
output_path = os.path.join(os.getcwd(), f"projects/crispy_shifties/{simulation_name}")
os.makedirs(output_path, exist_ok=True)
pdbs_path = os.path.join(output_path, "pdbs")
os.makedirs(pdbs_path, exist_ok=True)

pposes = design_after_repeat_propagation(
    None,
    pdb_path=hinge,
    models="all",
    num_repeats_extended=num_repeats_extended,
    num_sequences=8,
)

for i, p in enumerate(pposes):
    p.pose.dump_pdb(os.path.join(pdbs_path, f"{basename}_{str(i).zfill(4)}.pdb"))

# %%
hinge = "/mnt/home/flop/switch/5thround/extend/cs221_Y_n2c2.pdb"
basename = "cs_221AB_n2c2"
num_repeats_extended = 2

sys.path.insert(0, "/projects/crispy_shifty")
from crispy_shifty.protocols.cleaning import design_after_repeat_propagation

simulation_name = "11_make_extensions"
output_path = os.path.join(os.getcwd(), f"projects/crispy_shifties/{simulation_name}")
os.makedirs(output_path, exist_ok=True)
pdbs_path = os.path.join(output_path, "pdbs")
os.makedirs(pdbs_path, exist_ok=True)

pposes = design_after_repeat_propagation(
    None,
    pdb_path=hinge,
    max_recycles=5,
    models="all",
    no_filter_on_rmsd=True,
    num_repeats_extended=num_repeats_extended,
    num_sequences=8,
)

for i, p in enumerate(pposes):
    p.pose.dump_pdb(os.path.join(pdbs_path, f"{basename}_{str(i).zfill(4)}.pdb"))

# %%
sys.path.insert(0, "/projects/crispy_shifty")
from crispy_shifty.protocols.cleaning import design_after_repeat_propagation

simulation_name = "11_make_extensions"
output_path = os.path.join(os.getcwd(), f"projects/crispy_shifties/{simulation_name}")
os.makedirs(output_path, exist_ok=True)
pdbs_path = os.path.join(output_path, "pdbs")
os.makedirs(pdbs_path, exist_ok=True)

hinges = glob(
    "/mnt/home/flop/switch/5thround/alphafold/extend_hinges/done/cs221_YB_*2*v3.pdb"
)
for hinge in hinges:
    ext_type = hinge.split("YB_")[-1].replace("v3.pdb", "")
    basename = f"cs_221AB_{ext_type}"
    n_extended = ext_type[1]
    c_extended = ext_type[3]
    pposes = design_after_repeat_propagation(
        None,
        pdb_path=hinge,
        max_recycles=5,
        models="all",
        # no_filter_on_rmsd=True,
        n_extended=n_extended,
        c_extended=c_extended,
        neighborhood_distance=7,
        num_sequences=24,
    )

    for i, p in enumerate(pposes):
        p.pose.dump_pdb(os.path.join(pdbs_path, f"{basename}_{str(i).zfill(4)}.pdb"))
# Out:
# Scores may be absent or incorrectly formatted
# 0.02 min: Redesigning caps with MPNN
#
# ----------------------------------------
# pssm_jsonl is NOT loaded
# ----------------------------------------
# omit_AA_jsonl is NOT loaded
# ----------------------------------------
# bias_AA_jsonl is NOT loaded
# ----------------------------------------
# tied_positions_jsonl is NOT loaded
# ----------------------------------------
# bias by residue dictionary is not loaded, or not provided
# ----------------------------------------
# discarded {'bad_chars': 0, 'too_long': 0, 'bad_seq_length': 0}
# ----------------------------------------
# Number of edges: 48
# Training noise level: 0.1A
# Generating sequences for: tmp
# 24 sequences of length 294 generated in 1.3426 seconds
#
# 0.14 min: MPNN design complete, updating pose datacache
# 0.14 min: Filtering sequences with AF2
# 0.14 min: Setting up for AF2
# 0.14 min: Running AF2
# Warning: use "from pymol import cmd" instead of "import cmd"
# using  gpu
# =======================================================================================
# WARNING: Your querys are shorter than 400 residues. This is a very small protein.
# You may want to use the CPU to conserve GPU resources for those who need them.
# Remember that you can launch far more jobs in parallel on CPUs than you can on GPUs...
# See this example of how prediction time scales on CPU vs GPU:
# https://docs.google.com/spreadsheets/d/1jTGITpIx6fJehAplUkXtePOp7me3Dpq_pPKHn68F7XY
# =======================================================================================
# mpnn_seq_0000 model_1_ptm_seed_0 recycles:5 tol:0.59 mean_plddt:91.76 pTMscore:0.77 rmsd_to_reference:14.65 elapsed time (s): 210.9993817806244
# mpnn_seq_0000 model_2_ptm_seed_0 recycles:5 tol:1.91 mean_plddt:84.88 pTMscore:0.69 rmsd_to_reference:15.89 elapsed time (s): 34.26613259315491
# mpnn_seq_0000 model_3_ptm_seed_0 recycles:5 tol:0.46 mean_plddt:92.72 pTMscore:0.78 rmsd_to_reference:13.99 elapsed time (s): 34.940526247024536
# mpnn_seq_0000 model_4_ptm_seed_0 recycles:5 tol:0.23 mean_plddt:91.77 pTMscore:0.78 rmsd_to_reference:15.00 elapsed time (s): 34.28140044212341
# mpnn_seq_0000 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:94.96 pTMscore:0.88 rmsd_to_reference:1.00 elapsed time (s): 34.00590443611145
# mpnn_seq_0001 model_1_ptm_seed_0 recycles:5 tol:0.53 mean_plddt:92.55 pTMscore:0.78 rmsd_to_reference:14.38 elapsed time (s): 35.20101714134216
# mpnn_seq_0001 model_2_ptm_seed_0 recycles:5 tol:0.29 mean_plddt:83.85 pTMscore:0.67 rmsd_to_reference:16.20 elapsed time (s): 34.058714389801025
# mpnn_seq_0001 model_3_ptm_seed_0 recycles:5 tol:0.56 mean_plddt:92.87 pTMscore:0.77 rmsd_to_reference:14.04 elapsed time (s): 34.04416871070862
# mpnn_seq_0001 model_4_ptm_seed_0 recycles:5 tol:0.15 mean_plddt:92.40 pTMscore:0.78 rmsd_to_reference:14.87 elapsed time (s): 34.00936007499695
# mpnn_seq_0001 model_5_ptm_seed_0 recycles:5 tol:0.04 mean_plddt:95.52 pTMscore:0.89 rmsd_to_reference:1.09 elapsed time (s): 34.01608610153198
# mpnn_seq_0002 model_1_ptm_seed_0 recycles:5 tol:1.85 mean_plddt:92.61 pTMscore:0.77 rmsd_to_reference:16.30 elapsed time (s): 35.21839499473572
# mpnn_seq_0002 model_2_ptm_seed_0 recycles:5 tol:0.20 mean_plddt:84.77 pTMscore:0.67 rmsd_to_reference:18.37 elapsed time (s): 33.99266314506531
# mpnn_seq_0002 model_3_ptm_seed_0 recycles:5 tol:0.59 mean_plddt:93.61 pTMscore:0.78 rmsd_to_reference:14.26 elapsed time (s): 34.143346071243286
# mpnn_seq_0002 model_4_ptm_seed_0 recycles:5 tol:0.23 mean_plddt:92.90 pTMscore:0.78 rmsd_to_reference:14.73 elapsed time (s): 34.03687310218811
# mpnn_seq_0002 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.71 pTMscore:0.89 rmsd_to_reference:1.04 elapsed time (s): 33.95516753196716
# mpnn_seq_0003 model_1_ptm_seed_0 recycles:5 tol:0.53 mean_plddt:92.19 pTMscore:0.77 rmsd_to_reference:14.51 elapsed time (s): 35.53121590614319
# mpnn_seq_0003 model_2_ptm_seed_0 recycles:5 tol:0.41 mean_plddt:91.70 pTMscore:0.78 rmsd_to_reference:15.86 elapsed time (s): 34.01325178146362
# mpnn_seq_0003 model_3_ptm_seed_0 recycles:5 tol:0.31 mean_plddt:92.63 pTMscore:0.77 rmsd_to_reference:13.86 elapsed time (s): 34.04825019836426
# mpnn_seq_0003 model_4_ptm_seed_0 recycles:5 tol:0.18 mean_plddt:92.31 pTMscore:0.77 rmsd_to_reference:14.88 elapsed time (s): 33.992223024368286
# mpnn_seq_0003 model_5_ptm_seed_0 recycles:5 tol:0.02 mean_plddt:95.15 pTMscore:0.89 rmsd_to_reference:1.04 elapsed time (s): 34.04072117805481
# mpnn_seq_0004 model_1_ptm_seed_0 recycles:5 tol:0.73 mean_plddt:92.49 pTMscore:0.77 rmsd_to_reference:14.49 elapsed time (s): 35.17417645454407
# mpnn_seq_0004 model_2_ptm_seed_0 recycles:5 tol:1.61 mean_plddt:82.16 pTMscore:0.67 rmsd_to_reference:18.97 elapsed time (s): 34.072566509246826
# mpnn_seq_0004 model_3_ptm_seed_0 recycles:5 tol:0.45 mean_plddt:93.36 pTMscore:0.78 rmsd_to_reference:13.75 elapsed time (s): 34.00182127952576
# mpnn_seq_0004 model_4_ptm_seed_0 recycles:5 tol:0.12 mean_plddt:92.80 pTMscore:0.77 rmsd_to_reference:14.26 elapsed time (s): 34.031967639923096
# mpnn_seq_0004 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.68 pTMscore:0.89 rmsd_to_reference:0.98 elapsed time (s): 34.00186038017273
# mpnn_seq_0005 model_1_ptm_seed_0 recycles:5 tol:0.97 mean_plddt:92.14 pTMscore:0.77 rmsd_to_reference:14.47 elapsed time (s): 35.11612153053284
# mpnn_seq_0005 model_2_ptm_seed_0 recycles:5 tol:0.37 mean_plddt:81.41 pTMscore:0.65 rmsd_to_reference:19.08 elapsed time (s): 34.01862049102783
# mpnn_seq_0005 model_3_ptm_seed_0 recycles:5 tol:0.58 mean_plddt:93.48 pTMscore:0.79 rmsd_to_reference:13.36 elapsed time (s): 33.94794178009033
# mpnn_seq_0005 model_4_ptm_seed_0 recycles:5 tol:0.14 mean_plddt:92.30 pTMscore:0.78 rmsd_to_reference:14.77 elapsed time (s): 34.019981384277344
# mpnn_seq_0005 model_5_ptm_seed_0 recycles:5 tol:0.19 mean_plddt:94.09 pTMscore:0.80 rmsd_to_reference:13.96 elapsed time (s): 33.98982858657837
# mpnn_seq_0006 model_1_ptm_seed_0 recycles:5 tol:0.46 mean_plddt:91.88 pTMscore:0.77 rmsd_to_reference:15.25 elapsed time (s): 35.10596966743469
# mpnn_seq_0006 model_2_ptm_seed_0 recycles:5 tol:0.67 mean_plddt:90.99 pTMscore:0.78 rmsd_to_reference:16.61 elapsed time (s): 33.994954109191895
# mpnn_seq_0006 model_3_ptm_seed_0 recycles:5 tol:0.37 mean_plddt:92.76 pTMscore:0.77 rmsd_to_reference:13.69 elapsed time (s): 33.93739342689514
# mpnn_seq_0006 model_4_ptm_seed_0 recycles:5 tol:0.25 mean_plddt:92.07 pTMscore:0.77 rmsd_to_reference:14.21 elapsed time (s): 34.02099561691284
# mpnn_seq_0006 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.12 pTMscore:0.89 rmsd_to_reference:0.87 elapsed time (s): 33.99725103378296
# mpnn_seq_0007 model_1_ptm_seed_0 recycles:5 tol:0.61 mean_plddt:92.44 pTMscore:0.77 rmsd_to_reference:14.93 elapsed time (s): 35.2015495300293
# mpnn_seq_0007 model_2_ptm_seed_0 recycles:5 tol:1.18 mean_plddt:83.99 pTMscore:0.68 rmsd_to_reference:17.52 elapsed time (s): 34.06775760650635
# mpnn_seq_0007 model_3_ptm_seed_0 recycles:5 tol:0.32 mean_plddt:93.09 pTMscore:0.78 rmsd_to_reference:14.22 elapsed time (s): 33.98101592063904
# mpnn_seq_0007 model_4_ptm_seed_0 recycles:5 tol:0.20 mean_plddt:92.63 pTMscore:0.77 rmsd_to_reference:14.70 elapsed time (s): 33.98131728172302
# mpnn_seq_0007 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.04 pTMscore:0.88 rmsd_to_reference:0.93 elapsed time (s): 33.93881130218506
# mpnn_seq_0008 model_1_ptm_seed_0 recycles:5 tol:0.20 mean_plddt:92.38 pTMscore:0.78 rmsd_to_reference:14.46 elapsed time (s): 35.04142189025879
# mpnn_seq_0008 model_2_ptm_seed_0 recycles:5 tol:0.64 mean_plddt:84.25 pTMscore:0.66 rmsd_to_reference:18.54 elapsed time (s): 34.00573182106018
# mpnn_seq_0008 model_3_ptm_seed_0 recycles:5 tol:0.27 mean_plddt:93.13 pTMscore:0.78 rmsd_to_reference:13.96 elapsed time (s): 33.98747897148132
# mpnn_seq_0008 model_4_ptm_seed_0 recycles:5 tol:0.18 mean_plddt:92.64 pTMscore:0.78 rmsd_to_reference:14.83 elapsed time (s): 33.96270680427551
# mpnn_seq_0008 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.38 pTMscore:0.89 rmsd_to_reference:1.05 elapsed time (s): 33.98583173751831
# mpnn_seq_0009 model_1_ptm_seed_0 recycles:5 tol:0.43 mean_plddt:92.31 pTMscore:0.77 rmsd_to_reference:14.68 elapsed time (s): 35.0676965713501
# mpnn_seq_0009 model_2_ptm_seed_0 recycles:5 tol:2.00 mean_plddt:84.23 pTMscore:0.66 rmsd_to_reference:19.85 elapsed time (s): 33.998069524765015
# mpnn_seq_0009 model_3_ptm_seed_0 recycles:5 tol:0.40 mean_plddt:93.31 pTMscore:0.78 rmsd_to_reference:13.81 elapsed time (s): 34.006354093551636
# mpnn_seq_0009 model_4_ptm_seed_0 recycles:5 tol:0.11 mean_plddt:92.70 pTMscore:0.77 rmsd_to_reference:14.32 elapsed time (s): 33.97282600402832
# mpnn_seq_0009 model_5_ptm_seed_0 recycles:5 tol:0.02 mean_plddt:95.46 pTMscore:0.88 rmsd_to_reference:0.94 elapsed time (s): 33.97911715507507
# mpnn_seq_0010 model_1_ptm_seed_0 recycles:5 tol:0.36 mean_plddt:92.43 pTMscore:0.78 rmsd_to_reference:13.71 elapsed time (s): 35.610193490982056
# mpnn_seq_0010 model_2_ptm_seed_0 recycles:5 tol:0.16 mean_plddt:82.05 pTMscore:0.66 rmsd_to_reference:19.29 elapsed time (s): 33.98835802078247
# mpnn_seq_0010 model_3_ptm_seed_0 recycles:5 tol:0.31 mean_plddt:93.76 pTMscore:0.79 rmsd_to_reference:13.46 elapsed time (s): 34.01585650444031
# mpnn_seq_0010 model_4_ptm_seed_0 recycles:5 tol:0.37 mean_plddt:93.12 pTMscore:0.78 rmsd_to_reference:14.85 elapsed time (s): 33.94258522987366
# mpnn_seq_0010 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.32 pTMscore:0.89 rmsd_to_reference:1.18 elapsed time (s): 34.00672221183777
# mpnn_seq_0011 model_1_ptm_seed_0 recycles:5 tol:0.33 mean_plddt:92.17 pTMscore:0.77 rmsd_to_reference:16.40 elapsed time (s): 35.106749057769775
# mpnn_seq_0011 model_2_ptm_seed_0 recycles:5 tol:0.41 mean_plddt:83.35 pTMscore:0.68 rmsd_to_reference:20.13 elapsed time (s): 34.04364013671875
# mpnn_seq_0011 model_3_ptm_seed_0 recycles:5 tol:0.40 mean_plddt:92.58 pTMscore:0.77 rmsd_to_reference:14.21 elapsed time (s): 33.94298219680786
# mpnn_seq_0011 model_4_ptm_seed_0 recycles:5 tol:0.11 mean_plddt:92.10 pTMscore:0.77 rmsd_to_reference:14.29 elapsed time (s): 34.01099991798401
# mpnn_seq_0011 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.12 pTMscore:0.89 rmsd_to_reference:1.02 elapsed time (s): 33.974419832229614
# mpnn_seq_0012 model_1_ptm_seed_0 recycles:5 tol:0.67 mean_plddt:92.51 pTMscore:0.78 rmsd_to_reference:14.81 elapsed time (s): 35.14945840835571
# mpnn_seq_0012 model_2_ptm_seed_0 recycles:5 tol:0.34 mean_plddt:85.09 pTMscore:0.68 rmsd_to_reference:19.04 elapsed time (s): 33.97283315658569
# mpnn_seq_0012 model_3_ptm_seed_0 recycles:5 tol:0.59 mean_plddt:93.30 pTMscore:0.78 rmsd_to_reference:14.16 elapsed time (s): 34.0068724155426
# mpnn_seq_0012 model_4_ptm_seed_0 recycles:5 tol:0.19 mean_plddt:92.63 pTMscore:0.77 rmsd_to_reference:15.15 elapsed time (s): 33.97434377670288
# mpnn_seq_0012 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.30 pTMscore:0.88 rmsd_to_reference:1.00 elapsed time (s): 33.94950246810913
# mpnn_seq_0013 model_1_ptm_seed_0 recycles:5 tol:1.11 mean_plddt:92.42 pTMscore:0.77 rmsd_to_reference:14.99 elapsed time (s): 35.07621097564697
# mpnn_seq_0013 model_2_ptm_seed_0 recycles:5 tol:0.37 mean_plddt:91.29 pTMscore:0.78 rmsd_to_reference:16.42 elapsed time (s): 33.97726583480835
# mpnn_seq_0013 model_3_ptm_seed_0 recycles:5 tol:0.17 mean_plddt:93.28 pTMscore:0.78 rmsd_to_reference:13.84 elapsed time (s): 33.94694995880127
# mpnn_seq_0013 model_4_ptm_seed_0 recycles:5 tol:0.22 mean_plddt:92.85 pTMscore:0.78 rmsd_to_reference:14.11 elapsed time (s): 33.98004102706909
# mpnn_seq_0013 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.89 pTMscore:0.89 rmsd_to_reference:0.98 elapsed time (s): 33.95671558380127
# mpnn_seq_0014 model_1_ptm_seed_0 recycles:5 tol:1.49 mean_plddt:92.46 pTMscore:0.78 rmsd_to_reference:14.58 elapsed time (s): 35.05909705162048
# mpnn_seq_0014 model_2_ptm_seed_0 recycles:5 tol:0.47 mean_plddt:82.96 pTMscore:0.65 rmsd_to_reference:16.97 elapsed time (s): 33.95866799354553
# mpnn_seq_0014 model_3_ptm_seed_0 recycles:5 tol:0.64 mean_plddt:93.37 pTMscore:0.78 rmsd_to_reference:13.80 elapsed time (s): 33.96302390098572
# mpnn_seq_0014 model_4_ptm_seed_0 recycles:5 tol:0.16 mean_plddt:92.76 pTMscore:0.78 rmsd_to_reference:14.33 elapsed time (s): 33.97249627113342
# mpnn_seq_0014 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.45 pTMscore:0.89 rmsd_to_reference:1.02 elapsed time (s): 33.940383195877075
# mpnn_seq_0015 model_1_ptm_seed_0 recycles:5 tol:0.54 mean_plddt:92.43 pTMscore:0.77 rmsd_to_reference:16.31 elapsed time (s): 35.0964560508728
# mpnn_seq_0015 model_2_ptm_seed_0 recycles:5 tol:0.28 mean_plddt:83.66 pTMscore:0.66 rmsd_to_reference:18.01 elapsed time (s): 33.970502614974976
# mpnn_seq_0015 model_3_ptm_seed_0 recycles:5 tol:0.42 mean_plddt:93.03 pTMscore:0.78 rmsd_to_reference:14.07 elapsed time (s): 33.96325445175171
# mpnn_seq_0015 model_4_ptm_seed_0 recycles:5 tol:0.19 mean_plddt:92.59 pTMscore:0.78 rmsd_to_reference:14.25 elapsed time (s): 33.97480845451355
# mpnn_seq_0015 model_5_ptm_seed_0 recycles:5 tol:0.02 mean_plddt:95.49 pTMscore:0.89 rmsd_to_reference:1.02 elapsed time (s): 33.95858144760132
# mpnn_seq_0016 model_1_ptm_seed_0 recycles:5 tol:0.49 mean_plddt:92.24 pTMscore:0.77 rmsd_to_reference:14.86 elapsed time (s): 35.06251645088196
# mpnn_seq_0016 model_2_ptm_seed_0 recycles:5 tol:0.62 mean_plddt:83.91 pTMscore:0.68 rmsd_to_reference:12.37 elapsed time (s): 33.97151589393616
# mpnn_seq_0016 model_3_ptm_seed_0 recycles:5 tol:0.47 mean_plddt:92.60 pTMscore:0.77 rmsd_to_reference:14.16 elapsed time (s): 33.9752311706543
# mpnn_seq_0016 model_4_ptm_seed_0 recycles:5 tol:0.17 mean_plddt:92.08 pTMscore:0.78 rmsd_to_reference:14.51 elapsed time (s): 34.06081962585449
# mpnn_seq_0016 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.20 pTMscore:0.89 rmsd_to_reference:1.06 elapsed time (s): 34.04567360877991
# mpnn_seq_0017 model_1_ptm_seed_0 recycles:5 tol:0.45 mean_plddt:92.58 pTMscore:0.77 rmsd_to_reference:15.05 elapsed time (s): 35.13669276237488
# mpnn_seq_0017 model_2_ptm_seed_0 recycles:5 tol:0.09 mean_plddt:87.26 pTMscore:0.69 rmsd_to_reference:16.95 elapsed time (s): 34.048677921295166
# mpnn_seq_0017 model_3_ptm_seed_0 recycles:5 tol:0.47 mean_plddt:93.29 pTMscore:0.78 rmsd_to_reference:14.06 elapsed time (s): 34.03758120536804
# mpnn_seq_0017 model_4_ptm_seed_0 recycles:5 tol:0.86 mean_plddt:92.73 pTMscore:0.78 rmsd_to_reference:14.75 elapsed time (s): 34.025848388671875
# mpnn_seq_0017 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.73 pTMscore:0.89 rmsd_to_reference:1.01 elapsed time (s): 34.023834466934204
# mpnn_seq_0018 model_1_ptm_seed_0 recycles:5 tol:0.65 mean_plddt:92.42 pTMscore:0.77 rmsd_to_reference:14.72 elapsed time (s): 35.135579109191895
# mpnn_seq_0018 model_2_ptm_seed_0 recycles:5 tol:0.52 mean_plddt:82.35 pTMscore:0.67 rmsd_to_reference:21.63 elapsed time (s): 34.03157019615173
# mpnn_seq_0018 model_3_ptm_seed_0 recycles:5 tol:0.50 mean_plddt:93.56 pTMscore:0.78 rmsd_to_reference:14.36 elapsed time (s): 34.02737236022949
# mpnn_seq_0018 model_4_ptm_seed_0 recycles:5 tol:0.18 mean_plddt:92.92 pTMscore:0.77 rmsd_to_reference:15.01 elapsed time (s): 34.02995324134827
# mpnn_seq_0018 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.61 pTMscore:0.89 rmsd_to_reference:1.05 elapsed time (s): 34.02905321121216
# mpnn_seq_0019 model_1_ptm_seed_0 recycles:5 tol:0.50 mean_plddt:92.24 pTMscore:0.77 rmsd_to_reference:15.19 elapsed time (s): 35.73980116844177
# mpnn_seq_0019 model_2_ptm_seed_0 recycles:5 tol:0.18 mean_plddt:91.77 pTMscore:0.78 rmsd_to_reference:15.98 elapsed time (s): 34.06890892982483
# mpnn_seq_0019 model_3_ptm_seed_0 recycles:5 tol:0.42 mean_plddt:92.84 pTMscore:0.77 rmsd_to_reference:14.27 elapsed time (s): 34.01659941673279
# mpnn_seq_0019 model_4_ptm_seed_0 recycles:5 tol:0.21 mean_plddt:92.08 pTMscore:0.78 rmsd_to_reference:14.33 elapsed time (s): 34.045565366744995
# mpnn_seq_0019 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:94.93 pTMscore:0.89 rmsd_to_reference:1.07 elapsed time (s): 33.99487066268921
# mpnn_seq_0020 model_1_ptm_seed_0 recycles:5 tol:0.50 mean_plddt:92.70 pTMscore:0.78 rmsd_to_reference:14.41 elapsed time (s): 35.192657470703125
# mpnn_seq_0020 model_2_ptm_seed_0 recycles:5 tol:0.20 mean_plddt:89.45 pTMscore:0.72 rmsd_to_reference:18.43 elapsed time (s): 34.01961970329285
# mpnn_seq_0020 model_3_ptm_seed_0 recycles:5 tol:0.57 mean_plddt:93.30 pTMscore:0.78 rmsd_to_reference:14.33 elapsed time (s): 34.024755001068115
# mpnn_seq_0020 model_4_ptm_seed_0 recycles:5 tol:0.13 mean_plddt:92.73 pTMscore:0.78 rmsd_to_reference:14.53 elapsed time (s): 33.99292182922363
# mpnn_seq_0020 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.90 pTMscore:0.90 rmsd_to_reference:1.11 elapsed time (s): 34.027467012405396
# mpnn_seq_0021 model_1_ptm_seed_0 recycles:5 tol:0.95 mean_plddt:92.39 pTMscore:0.78 rmsd_to_reference:14.63 elapsed time (s): 35.174389600753784
# mpnn_seq_0021 model_2_ptm_seed_0 recycles:5 tol:2.58 mean_plddt:91.63 pTMscore:0.78 rmsd_to_reference:15.87 elapsed time (s): 34.0405170917511
# mpnn_seq_0021 model_3_ptm_seed_0 recycles:5 tol:0.53 mean_plddt:93.22 pTMscore:0.78 rmsd_to_reference:14.20 elapsed time (s): 34.029309034347534
# mpnn_seq_0021 model_4_ptm_seed_0 recycles:5 tol:0.32 mean_plddt:92.54 pTMscore:0.77 rmsd_to_reference:14.82 elapsed time (s): 34.010034799575806
# mpnn_seq_0021 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.55 pTMscore:0.89 rmsd_to_reference:1.11 elapsed time (s): 33.9806547164917
# mpnn_seq_0022 model_1_ptm_seed_0 recycles:5 tol:0.54 mean_plddt:92.41 pTMscore:0.78 rmsd_to_reference:14.87 elapsed time (s): 35.185651540756226
# mpnn_seq_0022 model_2_ptm_seed_0 recycles:5 tol:2.74 mean_plddt:90.48 pTMscore:0.79 rmsd_to_reference:5.76 elapsed time (s): 34.03645992279053
# mpnn_seq_0022 model_3_ptm_seed_0 recycles:5 tol:0.45 mean_plddt:93.18 pTMscore:0.78 rmsd_to_reference:14.05 elapsed time (s): 34.03071141242981
# mpnn_seq_0022 model_4_ptm_seed_0 recycles:5 tol:0.19 mean_plddt:92.48 pTMscore:0.78 rmsd_to_reference:14.81 elapsed time (s): 34.014004707336426
# mpnn_seq_0022 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.80 pTMscore:0.89 rmsd_to_reference:1.02 elapsed time (s): 33.99738359451294
# mpnn_seq_0023 model_1_ptm_seed_0 recycles:5 tol:1.83 mean_plddt:92.76 pTMscore:0.78 rmsd_to_reference:14.63 elapsed time (s): 35.074623346328735
# mpnn_seq_0023 model_2_ptm_seed_0 recycles:5 tol:0.34 mean_plddt:91.83 pTMscore:0.79 rmsd_to_reference:15.90 elapsed time (s): 33.98789191246033
# mpnn_seq_0023 model_3_ptm_seed_0 recycles:5 tol:0.63 mean_plddt:93.80 pTMscore:0.79 rmsd_to_reference:13.78 elapsed time (s): 33.943119287490845
# mpnn_seq_0023 model_4_ptm_seed_0 recycles:5 tol:0.29 mean_plddt:92.91 pTMscore:0.79 rmsd_to_reference:14.22 elapsed time (s): 33.99309682846069
# mpnn_seq_0023 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.99 pTMscore:0.90 rmsd_to_reference:1.07 elapsed time (s): 33.96184420585632
# mpnn_seq_0024 model_1_ptm_seed_0 recycles:5 tol:0.44 mean_plddt:92.46 pTMscore:0.77 rmsd_to_reference:14.86 elapsed time (s): 35.06955695152283
# mpnn_seq_0024 model_2_ptm_seed_0 recycles:5 tol:1.64 mean_plddt:82.64 pTMscore:0.66 rmsd_to_reference:17.93 elapsed time (s): 34.00131344795227
# mpnn_seq_0024 model_3_ptm_seed_0 recycles:5 tol:0.48 mean_plddt:93.17 pTMscore:0.77 rmsd_to_reference:13.70 elapsed time (s): 33.98295187950134
# mpnn_seq_0024 model_4_ptm_seed_0 recycles:5 tol:0.14 mean_plddt:92.38 pTMscore:0.77 rmsd_to_reference:14.14 elapsed time (s): 33.98918962478638
# mpnn_seq_0024 model_5_ptm_seed_0 recycles:5 tol:0.03 mean_plddt:95.19 pTMscore:0.89 rmsd_to_reference:0.98 elapsed time (s): 33.95781230926514
#
#   0%|          | 0/25 [00:00<?, ?it/s]
# Input: mpnn_seq_0000:   0%|          | 0/25 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:03<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [03:23<13:35, 203.76s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [03:25<13:35, 203.76s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:58<05:13, 104.46s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [04:00<05:13, 104.46s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [04:33<02:25, 72.72s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [04:35<02:25, 72.72s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [05:07<00:57, 57.54s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [05:09<00:57, 57.54s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [05:41<00:00, 49.05s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [05:43<00:00, 68.68s/it]
#
# Input: mpnn_seq_0000:   4%|▍         | 1/25 [05:43<2:17:28, 343.67s/it]
# Input: mpnn_seq_0001:   4%|▍         | 1/25 [05:43<2:17:28, 343.67s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.63s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:14, 33.63s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.88s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.88s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.95s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:07, 33.95s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.97s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:33, 33.97s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.98s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.24s/it]
#
# Input: mpnn_seq_0001:   8%|▊         | 2/25 [08:34<1:32:52, 242.29s/it]
# Input: mpnn_seq_0002:   8%|▊         | 2/25 [08:34<1:32:52, 242.29s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.62s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:14, 33.62s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.86s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.86s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.93s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:07, 33.93s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:34, 34.02s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:34, 34.02s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.99s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.24s/it]
#
# Input: mpnn_seq_0002:  12%|█▏        | 3/25 [11:26<1:16:57, 209.90s/it]
# Input: mpnn_seq_0003:  12%|█▏        | 3/25 [11:26<1:16:57, 209.90s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:15, 33.96s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:15, 33.96s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.99s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.99s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:08, 34.01s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:08, 34.01s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:34, 34.01s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:34, 34.01s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.02s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.30s/it]
#
# Input: mpnn_seq_0003:  16%|█▌        | 4/25 [14:17<1:08:10, 194.79s/it]
# Input: mpnn_seq_0004:  16%|█▌        | 4/25 [14:17<1:08:10, 194.79s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.60s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:14, 33.60s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.88s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.88s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.93s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:07, 33.93s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.97s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:33, 33.97s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.99s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.23s/it]
#
# Input: mpnn_seq_0004:  20%|██        | 5/25 [17:09<1:02:06, 186.31s/it]
# Input: mpnn_seq_0005:  20%|██        | 5/25 [17:09<1:02:06, 186.31s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.53s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:34<02:14, 33.53s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.82s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.82s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.88s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.88s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.93s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.93s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.96s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.19s/it]
#
# Input: mpnn_seq_0005:  24%|██▍       | 6/25 [20:00<57:21, 181.14s/it]
# Input: mpnn_seq_0006:  24%|██▍       | 6/25 [20:00<57:21, 181.14s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.54s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:34<02:14, 33.54s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.81s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:08<01:41, 33.81s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.86s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.86s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.93s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.93s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.95s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.19s/it]
#
# Input: mpnn_seq_0006:  28%|██▊       | 7/25 [22:51<53:21, 177.84s/it]
# Input: mpnn_seq_0007:  28%|██▊       | 7/25 [22:51<53:21, 177.84s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.63s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:14, 33.63s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.86s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.86s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.94s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:07, 33.94s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.95s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:33, 33.95s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.95s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.21s/it]
#
# Input: mpnn_seq_0007:  32%|███▏      | 8/25 [25:42<49:47, 175.72s/it]
# Input: mpnn_seq_0008:  32%|███▏      | 8/25 [25:42<49:47, 175.72s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:13, 33.48s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:34<02:13, 33.48s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.79s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:08<01:41, 33.79s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.88s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.88s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.91s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.91s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.94s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.17s/it]
#
# Input: mpnn_seq_0008:  36%|███▌      | 9/25 [28:33<46:27, 174.24s/it]
# Input: mpnn_seq_0009:  36%|███▌      | 9/25 [28:33<46:27, 174.24s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.51s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:34<02:14, 33.51s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.79s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:08<01:41, 33.79s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.89s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.89s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.92s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.92s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.94s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.18s/it]
#
# Input: mpnn_seq_0009:  40%|████      | 10/25 [31:24<43:18, 173.25s/it]
# Input: mpnn_seq_0010:  40%|████      | 10/25 [31:24<43:18, 173.25s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:34<02:16, 34.05s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:16, 34.05s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:08<01:42, 34.01s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:42, 34.01s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:08, 34.01s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:08, 34.01s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.99s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:33, 33.99s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.00s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.29s/it]
#
# Input: mpnn_seq_0010:  44%|████▍     | 11/25 [34:16<40:18, 172.73s/it]
# Input: mpnn_seq_0011:  44%|████▍     | 11/25 [34:16<40:18, 172.73s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.54s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:34<02:14, 33.54s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.83s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.83s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.89s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.89s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.94s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.94s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.95s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.19s/it]
#
# Input: mpnn_seq_0011:  48%|████▊     | 12/25 [37:07<37:18, 172.23s/it]
# Input: mpnn_seq_0012:  48%|████▊     | 12/25 [37:07<37:18, 172.23s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.59s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:14, 33.59s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.82s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:08<01:41, 33.82s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.89s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.89s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.93s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.93s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.94s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.18s/it]
#
# Input: mpnn_seq_0012:  52%|█████▏    | 13/25 [39:58<34:22, 171.87s/it]
# Input: mpnn_seq_0013:  52%|█████▏    | 13/25 [39:58<34:22, 171.87s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.51s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:34<02:14, 33.51s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.79s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:08<01:41, 33.79s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.86s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.86s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.88s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.88s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.93s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.16s/it]
#
# Input: mpnn_seq_0013:  56%|█████▌    | 14/25 [42:49<31:27, 171.59s/it]
# Input: mpnn_seq_0014:  56%|█████▌    | 14/25 [42:49<31:27, 171.59s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:13, 33.50s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:34<02:13, 33.50s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.77s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:08<01:41, 33.77s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.86s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.86s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.90s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.90s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.92s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.15s/it]
#
# Input: mpnn_seq_0014:  60%|██████    | 15/25 [45:40<28:33, 171.38s/it]
# Input: mpnn_seq_0015:  60%|██████    | 15/25 [45:40<28:33, 171.38s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.53s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:34<02:14, 33.53s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.79s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:08<01:41, 33.79s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.87s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.87s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.91s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.91s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.93s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.17s/it]
#
# Input: mpnn_seq_0015:  64%|██████▍   | 16/25 [48:31<25:41, 171.26s/it]
# Input: mpnn_seq_0016:  64%|██████▍   | 16/25 [48:31<25:41, 171.26s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.50s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:34<02:14, 33.50s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.78s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:08<01:41, 33.78s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.85s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.85s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.92s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.92s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.98s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.20s/it]
#
# Input: mpnn_seq_0016:  68%|██████▊   | 17/25 [51:22<22:49, 171.21s/it]
# Input: mpnn_seq_0017:  68%|██████▊   | 17/25 [51:22<22:49, 171.21s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.54s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:14, 33.54s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.84s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.84s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.93s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:07, 33.93s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.97s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:33, 33.97s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.99s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.23s/it]
#
# Input: mpnn_seq_0017:  72%|███████▏  | 18/25 [54:13<19:58, 171.23s/it]
# Input: mpnn_seq_0018:  72%|███████▏  | 18/25 [54:13<19:58, 171.23s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.55s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:14, 33.55s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.84s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.84s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.92s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:07, 33.92s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.96s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:33, 33.96s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.99s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.22s/it]
#
# Input: mpnn_seq_0018:  76%|███████▌  | 19/25 [57:04<17:07, 171.24s/it]
# Input: mpnn_seq_0019:  76%|███████▌  | 19/25 [57:04<17:07, 171.24s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.59s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:14, 33.59s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.87s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.87s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.94s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:07, 33.94s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.98s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:33, 33.98s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.99s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.24s/it]
#
# Input: mpnn_seq_0019:  80%|████████  | 20/25 [59:56<14:17, 171.43s/it]
# Input: mpnn_seq_0020:  80%|████████  | 20/25 [59:56<14:17, 171.43s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.59s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:14, 33.59s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.85s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.85s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.93s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:07, 33.93s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.95s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:33, 33.95s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.98s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.22s/it]
#
# Input: mpnn_seq_0020:  84%|████████▍ | 21/25 [1:02:47<11:25, 171.38s/it]
# Input: mpnn_seq_0021:  84%|████████▍ | 21/25 [1:02:47<11:25, 171.38s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.59s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:14, 33.59s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.85s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.85s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.93s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:07, 33.93s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.96s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:33, 33.96s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.97s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.22s/it]
#
# Input: mpnn_seq_0021:  88%|████████▊ | 22/25 [1:05:39<08:34, 171.33s/it]
# Input: mpnn_seq_0022:  88%|████████▊ | 22/25 [1:05:39<08:34, 171.33s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.59s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:35<02:14, 33.59s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.86s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:09<01:41, 33.86s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.94s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:43<01:07, 33.94s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.97s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:17<00:33, 33.97s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.98s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:51<00:00, 34.23s/it]
#
# Input: mpnn_seq_0022:  92%|█████████▏| 23/25 [1:08:30<05:42, 171.31s/it]
# Input: mpnn_seq_0023:  92%|█████████▏| 23/25 [1:08:30<05:42, 171.31s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.51s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:34<02:14, 33.51s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.79s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:08<01:41, 33.79s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.86s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.86s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.91s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.91s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.94s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.17s/it]
#
# Input: mpnn_seq_0023:  96%|█████████▌| 24/25 [1:11:21<02:51, 171.21s/it]
# Input: mpnn_seq_0024:  96%|█████████▌| 24/25 [1:11:21<02:51, 171.21s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [00:33<02:14, 33.50s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [00:34<02:14, 33.50s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [01:07<01:41, 33.80s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [01:08<01:41, 33.80s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [01:41<01:07, 33.88s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [01:42<01:07, 33.88s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [02:15<00:33, 33.92s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [02:16<00:33, 33.92s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:49<00:00, 33.94s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [02:50<00:00, 34.17s/it]
#
# Input: mpnn_seq_0024: 100%|██████████| 25/25 [1:14:12<00:00, 171.15s/it]
# Input: mpnn_seq_0024: 100%|██████████| 25/25 [1:14:12<00:00, 178.09s/it]
#
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 268
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 294
# ...
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ALA:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue SER:CtermProteinFull 307
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 333
# 100.09 min: AF2 complete, updating pose datacache
# 100.09 min: Adding passing sequences back into pose

# %%
sys.path.insert(0, "/projects/crispy_shifty")
from crispy_shifty.protocols.cleaning import design_after_repeat_propagation

simulation_name = "11_make_extensions"
output_path = os.path.join(os.getcwd(), f"projects/crispy_shifties/{simulation_name}")
os.makedirs(output_path, exist_ok=True)
pdbs_path = os.path.join(output_path, "pdbs")
os.makedirs(pdbs_path, exist_ok=True)

hinges = glob("/mnt/home/flop/switch/5thround/alphafold/extend_hinges/cs201_YB_*.pdb")
for hinge in hinges:
    ext_type = hinge.split("YB_")[-1].replace(".pdb", "")
    basename = f"cs_201AB_{ext_type}"
    n_extended = ext_type[1]
    c_extended = ext_type[3]
    pposes = design_after_repeat_propagation(
        None,
        pdb_path=hinge,
        max_recycles=5,
        models="all",
        n_extended=n_extended,
        c_extended=c_extended,
        neighborhood_distance=7,
        num_sequences=24,
    )

    for i, p in enumerate(pposes):
        p.pose.dump_pdb(os.path.join(pdbs_path, f"{basename}_{str(i).zfill(4)}.pdb"))
# Out:
# /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile
# Scores may be absent or incorrectly formatted
# 0.24 min: Redesigning caps with MPNN
#
# ----------------------------------------
# pssm_jsonl is NOT loaded
# ----------------------------------------
# omit_AA_jsonl is NOT loaded
# ----------------------------------------
# bias_AA_jsonl is NOT loaded
# ----------------------------------------
# tied_positions_jsonl is NOT loaded
# ----------------------------------------
# bias by residue dictionary is not loaded, or not provided
# ----------------------------------------
# discarded {'bad_chars': 0, 'too_long': 0, 'bad_seq_length': 0}
# ----------------------------------------
# Number of edges: 48
# Training noise level: 0.1A
# Generating sequences for: tmp
# 24 sequences of length 495 generated in 3.394 seconds
#
# 0.94 min: MPNN design complete, updating pose datacache
# 0.94 min: Filtering sequences with AF2
# 0.94 min: Setting up for AF2
# 0.94 min: Running AF2
# Warning: use "from pymol import cmd" instead of "import cmd"
# using  gpu
# mpnn_seq_0000 model_1_ptm_seed_0 recycles:5 tol:0.17 mean_plddt:92.61 pTMscore:0.85 rmsd_to_reference:2.18 elapsed time (s): 334.4433488845825
# mpnn_seq_0000 model_2_ptm_seed_0 recycles:5 tol:0.15 mean_plddt:91.82 pTMscore:0.81 rmsd_to_reference:13.39 elapsed time (s): 118.96841311454773
# mpnn_seq_0000 model_3_ptm_seed_0 recycles:5 tol:0.30 mean_plddt:93.43 pTMscore:0.81 rmsd_to_reference:7.51 elapsed time (s): 119.50817680358887
# mpnn_seq_0000 model_4_ptm_seed_0 recycles:5 tol:0.29 mean_plddt:91.56 pTMscore:0.82 rmsd_to_reference:2.46 elapsed time (s): 119.27771854400635
# mpnn_seq_0000 model_5_ptm_seed_0 recycles:5 tol:0.10 mean_plddt:92.54 pTMscore:0.85 rmsd_to_reference:2.52 elapsed time (s): 118.08605623245239
# mpnn_seq_0001 model_1_ptm_seed_0 recycles:5 tol:0.12 mean_plddt:93.25 pTMscore:0.84 rmsd_to_reference:1.59 elapsed time (s): 119.34927725791931
# mpnn_seq_0001 model_2_ptm_seed_0 recycles:5 tol:0.29 mean_plddt:92.90 pTMscore:0.80 rmsd_to_reference:9.52 elapsed time (s): 118.23477292060852
# mpnn_seq_0001 model_3_ptm_seed_0 recycles:5 tol:0.23 mean_plddt:92.90 pTMscore:0.83 rmsd_to_reference:1.94 elapsed time (s): 117.72561049461365
# mpnn_seq_0001 model_4_ptm_seed_0 recycles:5 tol:0.64 mean_plddt:92.35 pTMscore:0.77 rmsd_to_reference:13.08 elapsed time (s): 118.03993368148804
# mpnn_seq_0001 model_5_ptm_seed_0 recycles:5 tol:0.06 mean_plddt:92.83 pTMscore:0.84 rmsd_to_reference:2.10 elapsed time (s): 118.61615538597107
# mpnn_seq_0002 model_1_ptm_seed_0 recycles:5 tol:0.15 mean_plddt:92.72 pTMscore:0.84 rmsd_to_reference:1.98 elapsed time (s): 120.34823703765869
# mpnn_seq_0002 model_2_ptm_seed_0 recycles:5 tol:0.08 mean_plddt:92.03 pTMscore:0.80 rmsd_to_reference:12.84 elapsed time (s): 118.18515229225159
# mpnn_seq_0002 model_3_ptm_seed_0 recycles:5 tol:0.32 mean_plddt:93.64 pTMscore:0.81 rmsd_to_reference:7.51 elapsed time (s): 118.04978513717651
# mpnn_seq_0002 model_4_ptm_seed_0 recycles:5 tol:0.13 mean_plddt:92.11 pTMscore:0.81 rmsd_to_reference:2.06 elapsed time (s): 118.49694514274597
# mpnn_seq_0002 model_5_ptm_seed_0 recycles:5 tol:0.09 mean_plddt:92.45 pTMscore:0.83 rmsd_to_reference:2.42 elapsed time (s): 118.13342785835266
# mpnn_seq_0003 model_1_ptm_seed_0 recycles:5 tol:0.10 mean_plddt:92.52 pTMscore:0.84 rmsd_to_reference:1.67 elapsed time (s): 119.83404207229614
# mpnn_seq_0003 model_2_ptm_seed_0 recycles:5 tol:0.26 mean_plddt:92.47 pTMscore:0.80 rmsd_to_reference:9.53 elapsed time (s): 118.37162780761719
# mpnn_seq_0003 model_3_ptm_seed_0 recycles:5 tol:0.25 mean_plddt:92.69 pTMscore:0.82 rmsd_to_reference:2.16 elapsed time (s): 118.76917695999146
# mpnn_seq_0003 model_4_ptm_seed_0 recycles:5 tol:0.33 mean_plddt:92.06 pTMscore:0.78 rmsd_to_reference:8.37 elapsed time (s): 118.43544816970825
# mpnn_seq_0003 model_5_ptm_seed_0 recycles:5 tol:0.66 mean_plddt:92.12 pTMscore:0.84 rmsd_to_reference:2.39 elapsed time (s): 118.15998387336731
# mpnn_seq_0004 model_1_ptm_seed_0 recycles:5 tol:0.13 mean_plddt:93.38 pTMscore:0.84 rmsd_to_reference:1.88 elapsed time (s): 119.48955011367798
# mpnn_seq_0004 model_2_ptm_seed_0 recycles:5 tol:0.45 mean_plddt:92.76 pTMscore:0.80 rmsd_to_reference:9.29 elapsed time (s): 119.2198576927185
# mpnn_seq_0004 model_3_ptm_seed_0 recycles:5 tol:0.13 mean_plddt:93.45 pTMscore:0.83 rmsd_to_reference:1.97 elapsed time (s): 118.03256893157959
# mpnn_seq_0004 model_4_ptm_seed_0 recycles:5 tol:0.16 mean_plddt:92.29 pTMscore:0.81 rmsd_to_reference:2.22 elapsed time (s): 118.07387804985046
# mpnn_seq_0004 model_5_ptm_seed_0 recycles:5 tol:0.21 mean_plddt:92.65 pTMscore:0.84 rmsd_to_reference:2.48 elapsed time (s): 118.18364882469177
# mpnn_seq_0005 model_1_ptm_seed_0 recycles:5 tol:0.27 mean_plddt:92.51 pTMscore:0.83 rmsd_to_reference:1.75 elapsed time (s): 119.74502372741699
# mpnn_seq_0005 model_2_ptm_seed_0 recycles:5 tol:0.32 mean_plddt:92.12 pTMscore:0.80 rmsd_to_reference:7.34 elapsed time (s): 118.42058873176575
# mpnn_seq_0005 model_3_ptm_seed_0 recycles:5 tol:0.22 mean_plddt:93.37 pTMscore:0.80 rmsd_to_reference:7.53 elapsed time (s): 118.17924499511719
# mpnn_seq_0005 model_4_ptm_seed_0 recycles:5 tol:0.24 mean_plddt:91.99 pTMscore:0.78 rmsd_to_reference:8.79 elapsed time (s): 118.15039396286011
# mpnn_seq_0005 model_5_ptm_seed_0 recycles:5 tol:0.04 mean_plddt:92.27 pTMscore:0.84 rmsd_to_reference:2.52 elapsed time (s): 118.16927337646484
# mpnn_seq_0006 model_1_ptm_seed_0 recycles:5 tol:0.24 mean_plddt:92.73 pTMscore:0.84 rmsd_to_reference:1.97 elapsed time (s): 119.66023206710815
# mpnn_seq_0006 model_2_ptm_seed_0 recycles:5 tol:0.10 mean_plddt:92.03 pTMscore:0.81 rmsd_to_reference:12.80 elapsed time (s): 118.36411952972412
# mpnn_seq_0006 model_3_ptm_seed_0 recycles:5 tol:0.36 mean_plddt:93.92 pTMscore:0.81 rmsd_to_reference:7.75 elapsed time (s): 118.29029154777527
# mpnn_seq_0006 model_4_ptm_seed_0 recycles:5 tol:0.37 mean_plddt:92.54 pTMscore:0.81 rmsd_to_reference:9.46 elapsed time (s): 118.45233392715454
# mpnn_seq_0006 model_5_ptm_seed_0 recycles:5 tol:0.08 mean_plddt:92.60 pTMscore:0.83 rmsd_to_reference:2.35 elapsed time (s): 118.20142531394958
# mpnn_seq_0007 model_1_ptm_seed_0 recycles:5 tol:0.18 mean_plddt:91.39 pTMscore:0.83 rmsd_to_reference:2.81 elapsed time (s): 119.84720826148987
# mpnn_seq_0007 model_2_ptm_seed_0 recycles:5 tol:0.20 mean_plddt:91.52 pTMscore:0.80 rmsd_to_reference:12.91 elapsed time (s): 118.19229817390442
# mpnn_seq_0007 model_3_ptm_seed_0 recycles:5 tol:0.19 mean_plddt:92.03 pTMscore:0.80 rmsd_to_reference:2.50 elapsed time (s): 118.23318934440613
# mpnn_seq_0007 model_4_ptm_seed_0 recycles:5 tol:0.10 mean_plddt:91.76 pTMscore:0.80 rmsd_to_reference:1.99 elapsed time (s): 118.78918361663818
# mpnn_seq_0007 model_5_ptm_seed_0 recycles:5 tol:0.05 mean_plddt:91.54 pTMscore:0.83 rmsd_to_reference:2.70 elapsed time (s): 118.36194014549255
# mpnn_seq_0008 model_1_ptm_seed_0 recycles:5 tol:0.41 mean_plddt:92.76 pTMscore:0.83 rmsd_to_reference:2.43 elapsed time (s): 120.5321204662323
# mpnn_seq_0008 model_2_ptm_seed_0 recycles:5 tol:0.14 mean_plddt:92.35 pTMscore:0.80 rmsd_to_reference:12.97 elapsed time (s): 118.2996768951416
# mpnn_seq_0008 model_3_ptm_seed_0 recycles:5 tol:0.19 mean_plddt:93.03 pTMscore:0.80 rmsd_to_reference:7.38 elapsed time (s): 118.20153498649597
# mpnn_seq_0008 model_4_ptm_seed_0 recycles:5 tol:0.24 mean_plddt:91.98 pTMscore:0.80 rmsd_to_reference:9.33 elapsed time (s): 118.22929668426514
# mpnn_seq_0008 model_5_ptm_seed_0 recycles:5 tol:0.11 mean_plddt:92.57 pTMscore:0.84 rmsd_to_reference:2.71 elapsed time (s): 118.27014470100403
# mpnn_seq_0009 model_1_ptm_seed_0 recycles:5 tol:0.21 mean_plddt:93.14 pTMscore:0.84 rmsd_to_reference:2.18 elapsed time (s): 120.0358874797821
# mpnn_seq_0009 model_2_ptm_seed_0 recycles:5 tol:0.12 mean_plddt:92.72 pTMscore:0.81 rmsd_to_reference:12.47 elapsed time (s): 118.37372970581055
# mpnn_seq_0009 model_3_ptm_seed_0 recycles:5 tol:0.17 mean_plddt:91.32 pTMscore:0.79 rmsd_to_reference:4.46 elapsed time (s): 118.19511532783508
# mpnn_seq_0009 model_4_ptm_seed_0 recycles:5 tol:0.16 mean_plddt:92.70 pTMscore:0.80 rmsd_to_reference:7.69 elapsed time (s): 118.31399154663086
# mpnn_seq_0009 model_5_ptm_seed_0 recycles:5 tol:0.09 mean_plddt:93.19 pTMscore:0.85 rmsd_to_reference:2.20 elapsed time (s): 118.40410614013672
# mpnn_seq_0010 model_1_ptm_seed_0 recycles:5 tol:0.10 mean_plddt:92.54 pTMscore:0.84 rmsd_to_reference:1.42 elapsed time (s): 120.24930453300476
# mpnn_seq_0010 model_2_ptm_seed_0 recycles:5 tol:0.15 mean_plddt:91.79 pTMscore:0.80 rmsd_to_reference:12.53 elapsed time (s): 118.40293741226196
# mpnn_seq_0010 model_3_ptm_seed_0 recycles:5 tol:0.14 mean_plddt:91.09 pTMscore:0.80 rmsd_to_reference:4.35 elapsed time (s): 118.36817407608032
# mpnn_seq_0010 model_4_ptm_seed_0 recycles:5 tol:0.80 mean_plddt:92.17 pTMscore:0.79 rmsd_to_reference:8.34 elapsed time (s): 118.25387525558472
# mpnn_seq_0010 model_5_ptm_seed_0 recycles:5 tol:0.04 mean_plddt:92.48 pTMscore:0.84 rmsd_to_reference:2.31 elapsed time (s): 118.3748550415039
# mpnn_seq_0011 model_1_ptm_seed_0 recycles:5 tol:0.13 mean_plddt:93.13 pTMscore:0.84 rmsd_to_reference:1.64 elapsed time (s): 120.55117535591125
# mpnn_seq_0011 model_2_ptm_seed_0 recycles:5 tol:0.15 mean_plddt:92.33 pTMscore:0.81 rmsd_to_reference:12.55 elapsed time (s): 118.45294523239136
# mpnn_seq_0011 model_3_ptm_seed_0 recycles:5 tol:0.38 mean_plddt:92.00 pTMscore:0.80 rmsd_to_reference:2.28 elapsed time (s): 118.42308950424194
# mpnn_seq_0011 model_4_ptm_seed_0 recycles:5 tol:0.28 mean_plddt:92.37 pTMscore:0.78 rmsd_to_reference:13.13 elapsed time (s): 118.35364103317261
# mpnn_seq_0011 model_5_ptm_seed_0 recycles:5 tol:0.06 mean_plddt:92.75 pTMscore:0.84 rmsd_to_reference:2.36 elapsed time (s): 119.33970189094543
# mpnn_seq_0012 model_1_ptm_seed_0 recycles:5 tol:0.07 mean_plddt:92.92 pTMscore:0.84 rmsd_to_reference:1.80 elapsed time (s): 119.59132719039917
# mpnn_seq_0012 model_2_ptm_seed_0 recycles:5 tol:0.09 mean_plddt:92.19 pTMscore:0.80 rmsd_to_reference:12.57 elapsed time (s): 118.43350625038147
# mpnn_seq_0012 model_3_ptm_seed_0 recycles:5 tol:0.14 mean_plddt:93.22 pTMscore:0.80 rmsd_to_reference:7.18 elapsed time (s): 118.7078206539154
# mpnn_seq_0012 model_4_ptm_seed_0 recycles:5 tol:0.30 mean_plddt:92.05 pTMscore:0.82 rmsd_to_reference:2.17 elapsed time (s): 118.07690000534058
# mpnn_seq_0012 model_5_ptm_seed_0 recycles:5 tol:0.08 mean_plddt:93.07 pTMscore:0.85 rmsd_to_reference:2.25 elapsed time (s): 118.39555597305298
# mpnn_seq_0013 model_1_ptm_seed_0 recycles:5 tol:0.15 mean_plddt:92.62 pTMscore:0.83 rmsd_to_reference:1.53 elapsed time (s): 119.95622396469116
# mpnn_seq_0013 model_2_ptm_seed_0 recycles:5 tol:0.29 mean_plddt:91.70 pTMscore:0.80 rmsd_to_reference:9.13 elapsed time (s): 119.01255655288696
# mpnn_seq_0013 model_3_ptm_seed_0 recycles:5 tol:0.21 mean_plddt:92.43 pTMscore:0.82 rmsd_to_reference:1.92 elapsed time (s): 118.0834105014801
# mpnn_seq_0013 model_4_ptm_seed_0 recycles:5 tol:0.20 mean_plddt:91.73 pTMscore:0.81 rmsd_to_reference:1.85 elapsed time (s): 118.32569932937622
# mpnn_seq_0013 model_5_ptm_seed_0 recycles:5 tol:0.07 mean_plddt:91.35 pTMscore:0.84 rmsd_to_reference:2.81 elapsed time (s): 118.38753247261047
# mpnn_seq_0014 model_1_ptm_seed_0 recycles:5 tol:0.12 mean_plddt:93.27 pTMscore:0.84 rmsd_to_reference:1.55 elapsed time (s): 120.38930821418762
# mpnn_seq_0014 model_2_ptm_seed_0 recycles:5 tol:0.39 mean_plddt:93.22 pTMscore:0.81 rmsd_to_reference:9.20 elapsed time (s): 118.26781439781189
# mpnn_seq_0014 model_3_ptm_seed_0 recycles:5 tol:0.13 mean_plddt:93.62 pTMscore:0.84 rmsd_to_reference:1.72 elapsed time (s): 118.50090742111206
# mpnn_seq_0014 model_4_ptm_seed_0 recycles:5 tol:0.34 mean_plddt:92.57 pTMscore:0.80 rmsd_to_reference:8.04 elapsed time (s): 118.27271246910095
# mpnn_seq_0014 model_5_ptm_seed_0 recycles:5 tol:0.10 mean_plddt:92.91 pTMscore:0.85 rmsd_to_reference:2.15 elapsed time (s): 118.38239812850952
# mpnn_seq_0015 model_1_ptm_seed_0 recycles:5 tol:0.11 mean_plddt:92.65 pTMscore:0.83 rmsd_to_reference:0.87 elapsed time (s): 120.18874502182007
# mpnn_seq_0015 model_2_ptm_seed_0 recycles:5 tol:1.90 mean_plddt:91.30 pTMscore:0.79 rmsd_to_reference:7.22 elapsed time (s): 118.17539024353027
# mpnn_seq_0015 model_3_ptm_seed_0 recycles:5 tol:0.12 mean_plddt:92.62 pTMscore:0.81 rmsd_to_reference:2.08 elapsed time (s): 118.23456478118896
# mpnn_seq_0015 model_4_ptm_seed_0 recycles:5 tol:0.20 mean_plddt:91.41 pTMscore:0.80 rmsd_to_reference:1.76 elapsed time (s): 118.21841621398926
# mpnn_seq_0015 model_5_ptm_seed_0 recycles:5 tol:0.44 mean_plddt:92.06 pTMscore:0.84 rmsd_to_reference:2.01 elapsed time (s): 118.24745845794678
# mpnn_seq_0016 model_1_ptm_seed_0 recycles:5 tol:0.12 mean_plddt:92.44 pTMscore:0.84 rmsd_to_reference:1.47 elapsed time (s): 119.64435625076294
# mpnn_seq_0016 model_2_ptm_seed_0 recycles:5 tol:0.82 mean_plddt:91.19 pTMscore:0.80 rmsd_to_reference:8.09 elapsed time (s): 118.16179490089417
# mpnn_seq_0016 model_3_ptm_seed_0 recycles:5 tol:0.20 mean_plddt:92.32 pTMscore:0.82 rmsd_to_reference:1.76 elapsed time (s): 118.23715877532959
# mpnn_seq_0016 model_4_ptm_seed_0 recycles:5 tol:0.07 mean_plddt:89.95 pTMscore:0.76 rmsd_to_reference:6.99 elapsed time (s): 118.39675045013428
# mpnn_seq_0016 model_5_ptm_seed_0 recycles:5 tol:0.09 mean_plddt:91.15 pTMscore:0.83 rmsd_to_reference:2.16 elapsed time (s): 118.3745527267456
# mpnn_seq_0017 model_1_ptm_seed_0 recycles:5 tol:0.18 mean_plddt:93.08 pTMscore:0.84 rmsd_to_reference:1.77 elapsed time (s): 119.85603737831116
# mpnn_seq_0017 model_2_ptm_seed_0 recycles:5 tol:0.15 mean_plddt:91.92 pTMscore:0.80 rmsd_to_reference:12.28 elapsed time (s): 118.2659592628479
# mpnn_seq_0017 model_3_ptm_seed_0 recycles:5 tol:0.18 mean_plddt:92.11 pTMscore:0.81 rmsd_to_reference:2.15 elapsed time (s): 118.1545205116272
# mpnn_seq_0017 model_4_ptm_seed_0 recycles:5 tol:0.82 mean_plddt:91.90 pTMscore:0.77 rmsd_to_reference:13.36 elapsed time (s): 118.3999936580658
# mpnn_seq_0017 model_5_ptm_seed_0 recycles:5 tol:0.07 mean_plddt:92.60 pTMscore:0.84 rmsd_to_reference:2.21 elapsed time (s): 118.06829333305359
# mpnn_seq_0018 model_1_ptm_seed_0 recycles:5 tol:0.53 mean_plddt:92.98 pTMscore:0.84 rmsd_to_reference:2.02 elapsed time (s): 119.69863820075989
# mpnn_seq_0018 model_2_ptm_seed_0 recycles:5 tol:0.36 mean_plddt:93.13 pTMscore:0.80 rmsd_to_reference:16.22 elapsed time (s): 118.60205936431885
# mpnn_seq_0018 model_3_ptm_seed_0 recycles:5 tol:0.17 mean_plddt:93.48 pTMscore:0.84 rmsd_to_reference:1.85 elapsed time (s): 118.4267566204071
# mpnn_seq_0018 model_4_ptm_seed_0 recycles:5 tol:0.31 mean_plddt:92.93 pTMscore:0.79 rmsd_to_reference:13.01 elapsed time (s): 118.26302003860474
# mpnn_seq_0018 model_5_ptm_seed_0 recycles:5 tol:0.16 mean_plddt:93.11 pTMscore:0.84 rmsd_to_reference:2.16 elapsed time (s): 118.24141550064087
# mpnn_seq_0019 model_1_ptm_seed_0 recycles:5 tol:0.13 mean_plddt:92.72 pTMscore:0.84 rmsd_to_reference:1.45 elapsed time (s): 120.09938597679138
# mpnn_seq_0019 model_2_ptm_seed_0 recycles:5 tol:0.19 mean_plddt:91.74 pTMscore:0.80 rmsd_to_reference:8.59 elapsed time (s): 118.22855710983276
# mpnn_seq_0019 model_3_ptm_seed_0 recycles:5 tol:0.28 mean_plddt:93.13 pTMscore:0.80 rmsd_to_reference:7.13 elapsed time (s): 118.24531555175781
# mpnn_seq_0019 model_4_ptm_seed_0 recycles:5 tol:1.13 mean_plddt:91.76 pTMscore:0.78 rmsd_to_reference:7.78 elapsed time (s): 118.08076858520508
# mpnn_seq_0019 model_5_ptm_seed_0 recycles:5 tol:0.07 mean_plddt:92.22 pTMscore:0.83 rmsd_to_reference:2.19 elapsed time (s): 118.41626954078674
# mpnn_seq_0020 model_1_ptm_seed_0 recycles:5 tol:0.74 mean_plddt:92.44 pTMscore:0.84 rmsd_to_reference:1.74 elapsed time (s): 120.7611768245697
# mpnn_seq_0020 model_2_ptm_seed_0 recycles:5 tol:2.35 mean_plddt:91.67 pTMscore:0.80 rmsd_to_reference:7.16 elapsed time (s): 118.35440611839294
# mpnn_seq_0020 model_3_ptm_seed_0 recycles:5 tol:0.18 mean_plddt:92.29 pTMscore:0.81 rmsd_to_reference:2.27 elapsed time (s): 118.36249804496765
# mpnn_seq_0020 model_4_ptm_seed_0 recycles:5 tol:0.61 mean_plddt:90.26 pTMscore:0.78 rmsd_to_reference:1.91 elapsed time (s): 118.3017840385437
# mpnn_seq_0020 model_5_ptm_seed_0 recycles:5 tol:0.07 mean_plddt:92.34 pTMscore:0.84 rmsd_to_reference:2.15 elapsed time (s): 118.40736603736877
# mpnn_seq_0021 model_1_ptm_seed_0 recycles:5 tol:0.11 mean_plddt:92.93 pTMscore:0.84 rmsd_to_reference:2.11 elapsed time (s): 119.77118349075317
# mpnn_seq_0021 model_2_ptm_seed_0 recycles:5 tol:0.23 mean_plddt:91.90 pTMscore:0.80 rmsd_to_reference:9.64 elapsed time (s): 118.421790599823
# mpnn_seq_0021 model_3_ptm_seed_0 recycles:5 tol:0.18 mean_plddt:90.39 pTMscore:0.77 rmsd_to_reference:6.13 elapsed time (s): 118.24923515319824
# mpnn_seq_0021 model_4_ptm_seed_0 recycles:5 tol:0.37 mean_plddt:90.85 pTMscore:0.78 rmsd_to_reference:7.20 elapsed time (s): 118.3600206375122
# mpnn_seq_0021 model_5_ptm_seed_0 recycles:5 tol:0.08 mean_plddt:92.91 pTMscore:0.84 rmsd_to_reference:2.36 elapsed time (s): 118.35774302482605
# mpnn_seq_0022 model_1_ptm_seed_0 recycles:5 tol:0.11 mean_plddt:92.97 pTMscore:0.84 rmsd_to_reference:1.92 elapsed time (s): 119.7556962966919
# mpnn_seq_0022 model_2_ptm_seed_0 recycles:5 tol:1.00 mean_plddt:92.17 pTMscore:0.80 rmsd_to_reference:9.09 elapsed time (s): 118.5526921749115
# mpnn_seq_0022 model_3_ptm_seed_0 recycles:5 tol:0.24 mean_plddt:93.61 pTMscore:0.82 rmsd_to_reference:6.73 elapsed time (s): 118.58232879638672
# mpnn_seq_0022 model_4_ptm_seed_0 recycles:5 tol:1.20 mean_plddt:92.47 pTMscore:0.78 rmsd_to_reference:12.97 elapsed time (s): 118.27536177635193
# mpnn_seq_0022 model_5_ptm_seed_0 recycles:5 tol:0.07 mean_plddt:92.24 pTMscore:0.84 rmsd_to_reference:2.34 elapsed time (s): 118.40913438796997
# mpnn_seq_0023 model_1_ptm_seed_0 recycles:5 tol:0.30 mean_plddt:92.89 pTMscore:0.84 rmsd_to_reference:1.61 elapsed time (s): 120.67340326309204
# mpnn_seq_0023 model_2_ptm_seed_0 recycles:5 tol:0.37 mean_plddt:92.87 pTMscore:0.80 rmsd_to_reference:9.56 elapsed time (s): 118.91990995407104
# mpnn_seq_0023 model_3_ptm_seed_0 recycles:5 tol:0.15 mean_plddt:92.42 pTMscore:0.81 rmsd_to_reference:1.90 elapsed time (s): 118.19419050216675
# mpnn_seq_0023 model_4_ptm_seed_0 recycles:5 tol:0.21 mean_plddt:92.54 pTMscore:0.79 rmsd_to_reference:8.44 elapsed time (s): 117.98152017593384
# mpnn_seq_0023 model_5_ptm_seed_0 recycles:5 tol:0.07 mean_plddt:92.62 pTMscore:0.84 rmsd_to_reference:2.10 elapsed time (s): 118.42188453674316
# mpnn_seq_0024 model_1_ptm_seed_0 recycles:5 tol:0.10 mean_plddt:92.76 pTMscore:0.84 rmsd_to_reference:2.18 elapsed time (s): 119.73847913742065
# mpnn_seq_0024 model_2_ptm_seed_0 recycles:5 tol:0.38 mean_plddt:91.99 pTMscore:0.80 rmsd_to_reference:9.41 elapsed time (s): 118.25906252861023
# mpnn_seq_0024 model_3_ptm_seed_0 recycles:5 tol:0.26 mean_plddt:93.85 pTMscore:0.81 rmsd_to_reference:7.34 elapsed time (s): 118.45589113235474
# mpnn_seq_0024 model_4_ptm_seed_0 recycles:5 tol:0.25 mean_plddt:92.29 pTMscore:0.79 rmsd_to_reference:9.54 elapsed time (s): 118.00461769104004
# mpnn_seq_0024 model_5_ptm_seed_0 recycles:5 tol:0.10 mean_plddt:92.47 pTMscore:0.84 rmsd_to_reference:2.57 elapsed time (s): 118.16075658798218
#
#   0%|          | 0/25 [00:00<?, ?it/s]
# Input: mpnn_seq_0000:   0%|          | 0/25 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:13<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [04:49<19:17, 289.39s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [04:53<19:17, 289.39s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [06:49<09:28, 189.64s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [06:52<09:28, 189.64s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [08:48<05:15, 157.61s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [08:51<05:15, 157.61s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [10:47<02:22, 142.45s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [10:50<02:22, 142.45s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [12:45<00:00, 133.65s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [12:48<00:00, 153.78s/it]
#
# Input: mpnn_seq_0000:   4%|▍         | 1/25 [12:49<5:07:48, 769.51s/it]
# Input: mpnn_seq_0001:   4%|▍         | 1/25 [12:49<5:07:48, 769.51s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:44, 116.18s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:44, 116.18s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:54<05:52, 117.37s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:57<05:52, 117.37s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:52<03:55, 117.58s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:55<03:55, 117.58s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:50<01:57, 117.74s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:53<01:57, 117.74s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:48<00:00, 117.83s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:51<00:00, 118.34s/it]
#
# Input: mpnn_seq_0001:   8%|▊         | 2/25 [22:41<4:14:56, 665.07s/it]
# Input: mpnn_seq_0002:   8%|▊         | 2/25 [22:41<4:14:56, 665.07s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:47, 116.83s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:47, 116.83s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:52, 117.65s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:57<05:52, 117.65s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:55, 117.82s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:55<03:55, 117.82s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.03s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.03s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:49<00:00, 118.13s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.51s/it]
#
# Input: mpnn_seq_0002:  12%|█▏        | 3/25 [32:34<3:51:49, 632.26s/it]
# Input: mpnn_seq_0003:  12%|█▏        | 3/25 [32:34<3:51:49, 632.26s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:46, 116.74s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:46, 116.74s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:53, 117.69s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:57<05:53, 117.69s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:56, 118.04s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:56, 118.04s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:52<01:58, 118.31s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:55<01:58, 118.31s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:50<00:00, 118.27s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:53<00:00, 118.66s/it]
#
# Input: mpnn_seq_0003:  16%|█▌        | 4/25 [42:28<3:35:56, 616.99s/it]
# Input: mpnn_seq_0004:  16%|█▌        | 4/25 [42:28<3:35:56, 616.99s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:45, 116.40s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:45, 116.40s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:54<05:52, 117.51s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:52, 117.51s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:56, 118.18s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:56, 118.18s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.14s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.14s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:49<00:00, 118.14s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.55s/it]
#
# Input: mpnn_seq_0004:  20%|██        | 5/25 [52:21<3:22:46, 608.34s/it]
# Input: mpnn_seq_0005:  20%|██        | 5/25 [52:21<3:22:46, 608.34s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:46, 116.60s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:46, 116.60s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:53, 117.71s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:57<05:53, 117.71s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:55, 117.92s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:55, 117.92s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.00s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.00s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:49<00:00, 118.07s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.48s/it]
#
# Input: mpnn_seq_0005:  24%|██▍       | 6/25 [1:02:13<3:10:57, 603.01s/it]
# Input: mpnn_seq_0006:  24%|██▍       | 6/25 [1:02:13<3:10:57, 603.01s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:46, 116.58s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:46, 116.58s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:54<05:52, 117.64s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:57<05:52, 117.64s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:55, 117.93s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:55, 117.93s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.10s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.10s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:49<00:00, 118.17s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.54s/it]
#
# Input: mpnn_seq_0006:  28%|██▊       | 7/25 [1:12:06<2:59:55, 599.73s/it]
# Input: mpnn_seq_0007:  28%|██▊       | 7/25 [1:12:06<2:59:55, 599.73s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:47, 116.75s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:47, 116.75s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:54<05:52, 117.60s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:57<05:52, 117.60s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:55, 117.91s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:55, 117.91s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.02s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.02s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:50<00:00, 118.33s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:53<00:00, 118.63s/it]
#
# Input: mpnn_seq_0007:  32%|███▏      | 8/25 [1:22:00<2:49:21, 597.72s/it]
# Input: mpnn_seq_0008:  32%|███▏      | 8/25 [1:22:00<2:49:21, 597.72s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:57<07:49, 117.40s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [02:00<07:49, 117.40s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:53, 117.96s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:53, 117.96s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:56, 118.04s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:56, 118.04s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:52<01:58, 118.14s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:55<01:58, 118.14s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:50<00:00, 118.18s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:53<00:00, 118.65s/it]
#
# Input: mpnn_seq_0008:  36%|███▌      | 9/25 [1:31:53<2:39:02, 596.41s/it]
# Input: mpnn_seq_0009:  36%|███▌      | 9/25 [1:31:53<2:39:02, 596.41s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:47, 116.92s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:47, 116.92s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:53, 117.74s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:53, 117.74s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:55, 117.99s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:55, 117.99s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.10s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.10s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:50<00:00, 118.20s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:53<00:00, 118.61s/it]
#
# Input: mpnn_seq_0009:  40%|████      | 10/25 [1:41:47<2:28:51, 595.46s/it]
# Input: mpnn_seq_0010:  40%|████      | 10/25 [1:41:47<2:28:51, 595.46s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:46, 116.65s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:46, 116.65s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:53, 117.97s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:53, 117.97s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:56, 118.15s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:56, 118.15s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:52<01:58, 118.20s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:55<01:58, 118.20s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:50<00:00, 118.26s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:53<00:00, 118.68s/it]
#
# Input: mpnn_seq_0010:  44%|████▍     | 11/25 [1:51:40<2:18:48, 594.91s/it]
# Input: mpnn_seq_0011:  44%|████▍     | 11/25 [1:51:40<2:18:48, 594.91s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:57<07:49, 117.46s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [02:00<07:49, 117.46s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:54, 118.03s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:54, 118.03s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:54<03:56, 118.22s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:57<03:56, 118.22s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:52<01:58, 118.27s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:55<01:58, 118.27s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.66s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:54<00:00, 118.97s/it]
#
# Input: mpnn_seq_0011:  48%|████▊     | 12/25 [2:01:35<2:08:54, 594.97s/it]
# Input: mpnn_seq_0012:  48%|████▊     | 12/25 [2:01:35<2:08:54, 594.97s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:45, 116.49s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:45, 116.49s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:54<05:52, 117.64s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:57<05:52, 117.64s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:55, 117.98s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:55, 117.98s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.14s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.14s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:50<00:00, 118.22s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.59s/it]
#
# Input: mpnn_seq_0012:  52%|█████▏    | 13/25 [2:11:29<1:58:53, 594.44s/it]
# Input: mpnn_seq_0013:  52%|█████▏    | 13/25 [2:11:29<1:58:53, 594.44s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:47, 116.85s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:47, 116.85s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:53, 117.74s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:53, 117.74s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:56, 118.19s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:56, 118.19s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:52<01:58, 118.24s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:55<01:58, 118.24s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:50<00:00, 118.29s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:53<00:00, 118.70s/it]
#
# Input: mpnn_seq_0013:  56%|█████▌    | 14/25 [2:21:22<1:48:56, 594.23s/it]
# Input: mpnn_seq_0014:  56%|█████▌    | 14/25 [2:21:22<1:48:56, 594.23s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:57<07:49, 117.27s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [02:00<07:49, 117.27s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:53, 117.86s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:53, 117.86s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:54<03:56, 118.15s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:56, 118.15s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:52<01:58, 118.21s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:55<01:58, 118.21s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:50<00:00, 118.26s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:53<00:00, 118.71s/it]
#
# Input: mpnn_seq_0014:  60%|██████    | 15/25 [2:31:16<1:39:01, 594.11s/it]
# Input: mpnn_seq_0015:  60%|██████    | 15/25 [2:31:16<1:39:01, 594.11s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:57<07:48, 117.12s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:48, 117.12s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:53, 117.73s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:53, 117.73s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:55, 117.96s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:55, 117.96s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.06s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.06s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:49<00:00, 118.12s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.56s/it]
#
# Input: mpnn_seq_0015:  64%|██████▍   | 16/25 [2:41:09<1:29:04, 593.79s/it]
# Input: mpnn_seq_0016:  64%|██████▍   | 16/25 [2:41:09<1:29:04, 593.79s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:46, 116.54s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:46, 116.54s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:54<05:52, 117.52s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:57<05:52, 117.52s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:52<03:55, 117.84s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:55<03:55, 117.84s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.05s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.05s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:49<00:00, 118.16s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.51s/it]
#
# Input: mpnn_seq_0016:  68%|██████▊   | 17/25 [2:51:02<1:19:07, 593.50s/it]
# Input: mpnn_seq_0017:  68%|██████▊   | 17/25 [2:51:02<1:19:07, 593.50s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:47, 116.76s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:47, 116.76s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:52, 117.64s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:57<05:52, 117.64s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:55, 117.87s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:55, 117.87s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.08s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.08s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:49<00:00, 118.08s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.50s/it]
#
# Input: mpnn_seq_0017:  72%|███████▏  | 18/25 [3:00:55<1:09:12, 593.27s/it]
# Input: mpnn_seq_0018:  72%|███████▏  | 18/25 [3:00:55<1:09:12, 593.27s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:46, 116.58s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:46, 116.58s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:54<05:52, 117.42s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:52, 117.42s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:56, 118.15s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:56, 118.15s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.19s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.19s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:50<00:00, 118.21s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.59s/it]
#
# Input: mpnn_seq_0018:  76%|███████▌  | 19/25 [3:10:48<59:19, 593.26s/it]
# Input: mpnn_seq_0019:  76%|███████▌  | 19/25 [3:10:48<59:19, 593.26s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:46, 116.64s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:46, 116.64s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:53, 117.79s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:53, 117.79s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:55, 117.99s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:55, 117.99s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.02s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.02s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:49<00:00, 118.18s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.56s/it]
#
# Input: mpnn_seq_0019:  80%|████████  | 20/25 [3:20:41<49:26, 593.20s/it]
# Input: mpnn_seq_0020:  80%|████████  | 20/25 [3:20:41<49:26, 593.20s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:02<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:57<07:50, 117.68s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [02:00<07:50, 117.68s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:56<05:54, 118.08s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:54, 118.08s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:54<03:56, 118.21s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:57<03:56, 118.21s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:52<01:58, 118.24s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:55<01:58, 118.24s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:51<00:00, 118.30s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:53<00:00, 118.79s/it]
#
# Input: mpnn_seq_0020:  84%|████████▍ | 21/25 [3:30:35<39:33, 593.50s/it]
# Input: mpnn_seq_0021:  84%|████████▍ | 21/25 [3:30:35<39:33, 593.50s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:46, 116.65s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:46, 116.65s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:53, 117.68s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:57<05:53, 117.68s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:55, 117.95s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:55, 117.95s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.11s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.11s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:50<00:00, 118.20s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.58s/it]
#
# Input: mpnn_seq_0021:  88%|████████▊ | 22/25 [3:40:29<29:40, 593.40s/it]
# Input: mpnn_seq_0022:  88%|████████▊ | 22/25 [3:40:29<29:40, 593.40s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:46, 116.62s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:46, 116.62s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:55<05:53, 117.76s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:58<05:53, 117.76s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:56, 118.15s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:56, 118.15s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:52<01:58, 118.21s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.21s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:50<00:00, 118.28s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:53<00:00, 118.66s/it]
#
# Input: mpnn_seq_0022:  92%|█████████▏| 23/25 [3:50:22<19:46, 593.45s/it]
# Input: mpnn_seq_0023:  92%|█████████▏| 23/25 [3:50:22<19:46, 593.45s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:57<07:50, 117.60s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [02:00<07:50, 117.60s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:56<05:55, 118.38s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:59<05:55, 118.38s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:54<03:56, 118.30s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:57<03:56, 118.30s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:52<01:58, 118.16s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:55<01:58, 118.16s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:51<00:00, 118.26s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:53<00:00, 118.79s/it]
#
# Input: mpnn_seq_0023:  96%|█████████▌| 24/25 [4:00:16<09:53, 593.67s/it]
# Input: mpnn_seq_0024:  96%|█████████▌| 24/25 [4:00:16<09:53, 593.67s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
# Running model_1_ptm_seed_0:   0%|          | 0/5 [00:01<?, ?it/s]
#
# Running model_1_ptm_seed_0:  20%|██        | 1/5 [01:56<07:46, 116.68s/it]
#
# Running model_2_ptm_seed_0:  20%|██        | 1/5 [01:59<07:46, 116.68s/it]
#
# Running model_2_ptm_seed_0:  40%|████      | 2/5 [03:54<05:52, 117.59s/it]
#
# Running model_3_ptm_seed_0:  40%|████      | 2/5 [03:57<05:52, 117.59s/it]
#
# Running model_3_ptm_seed_0:  60%|██████    | 3/5 [05:53<03:56, 118.01s/it]
#
# Running model_4_ptm_seed_0:  60%|██████    | 3/5 [05:56<03:56, 118.01s/it]
#
# Running model_4_ptm_seed_0:  80%|████████  | 4/5 [07:51<01:58, 118.00s/it]
#
# Running model_5_ptm_seed_0:  80%|████████  | 4/5 [07:54<01:58, 118.00s/it]
#
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:49<00:00, 118.06s/it]
# Running model_5_ptm_seed_0: 100%|██████████| 5/5 [09:52<00:00, 118.47s/it]
#
# Input: mpnn_seq_0024: 100%|██████████| 25/25 [4:10:09<00:00, 593.36s/it]
# Input: mpnn_seq_0024: 100%|██████████| 25/25 [4:10:09<00:00, 600.38s/it]
#
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue VAL:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 465
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 495
# ...
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ASN:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ASN:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ASN:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ASN:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 407
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLU:CtermProteinFull 437
# 194.69 min: AF2 complete, updating pose datacache
# 194.69 min: Adding passing sequences back into pose

# %% [markdown]
# ### Make new extensions

# %%
def range_CA_align(pose1, pose2, start1, end1, start2, end2):
#modified from Adam's function (pose 1 mobile)
    pose1_residue_selection = range(start1,end1)
    pose2_residue_selection = range(start2,end2)
    
    assert len(pose1_residue_selection) == len(pose2_residue_selection)

    pose1_coordinates = pyrosetta.rosetta.utility.vector1_numeric_xyzVector_double_t()
    pose2_coordinates = pyrosetta.rosetta.utility.vector1_numeric_xyzVector_double_t()

    for pose1_residue_index, pose2_residue_index in zip(pose1_residue_selection, pose2_residue_selection):
        pose1_coordinates.append(pose1.residues[pose1_residue_index].xyz('CA'))
        pose2_coordinates.append(pose2.residues[pose2_residue_index].xyz('CA'))

    rotation_matrix = pyrosetta.rosetta.numeric.xyzMatrix_double_t()
    pose1_center = pyrosetta.rosetta.numeric.xyzVector_double_t()
    pose2_center = pyrosetta.rosetta.numeric.xyzVector_double_t()

    pyrosetta.rosetta.protocols.toolbox.superposition_transform(pose1_coordinates,
                                                                pose2_coordinates,
                                                                rotation_matrix,
                                                                pose1_center,
                                                                pose2_center)

    pyrosetta.rosetta.protocols.toolbox.apply_superposition_transform(pose1,
                                                                      rotation_matrix,
                                                                      pose1_center,
                                                                      pose2_center)
                     
def clash_check(pose):
    all_gly = pose.clone()
    true_sel = pyrosetta.rosetta.core.select.residue_selector.TrueResidueSelector()
    true_x = true_sel.apply(all_gly)
    pyrosetta.rosetta.protocols.toolbox.pose_manipulation.repack_these_residues(true_x, all_gly, sfxn, False, "G" )
    score = sfxn(all_gly)
    return score

def helix_dict(pose):
    #pose = pyrosetta.io.pose_from_pdb(filename)
    ss = pyrosetta.rosetta.core.scoring.dssp.Dssp(pose)
    hlx_dict = {}
    n = 1
    for i in range(1,len(pose.sequence())):
        if (ss.get_dssp_secstruct(i) == "H") & (ss.get_dssp_secstruct(i-1) !="H"):
            hlx_dict[n] = [i]
        if (ss.get_dssp_secstruct(i) == "H") & (ss.get_dssp_secstruct(i+1) !="H"):
            hlx_dict[n].append(i)
            n +=1
    return hlx_dict

def load_pose(name):
    if type(name) == str:
        pose = pyrosetta.io.pose_from_pdb(name)
    else:
        try:
            pose = name.clone()
        except:
            print("input must be a pose or a path to a pose")
    return pose


def swap_ab(name):
    pose_ab = load_pose(name)
    pose_ba = pose_ab.split_by_chain(2)
    pyrosetta.rosetta.core.pose.append_pose_to_pose(pose_ba,pose_ab.split_by_chain(1),1)
    return pose_ba
# swap_ab: normally assume that oligomer is chain A and heterodimer is chain B. If the other way round ,then do swap_ab

def extend_dhr(pose1,pose2, keep = "c", h1n = "last", h2n = "last", h1_c = 3, h2_c = 4):
    if type(pose1) == str:
        pose_n = pyrosetta.io.pose_from_pdb(pose1).split_by_chain(1)
    else:
        pose_n = pose1.split_by_chain(1)
    if type(pose2) == str:
        pose_c = pyrosetta.io.pose_from_pdb(pose2).split_by_chain(1)
    else:
        pose_c = pose2.split_by_chain(1)
    hdn = helix_dict(pose_n)
    hdc = helix_dict(pose_c)
    if (h1n == "last") or (h1n == -2):
        h1_n = list(hdn)[-2]
    else:
        h1_n = h1n
    if (h2n == "last") or (h2n == -1):
        h2_n = list(hdn)[-1]
    else:
        h2_n = h2n
    copy_c = pose_c.clone()
    newpose = pyrosetta.rosetta.core.pose.Pose()
    start_c = hdc[h1_c][0]
    end_c = hdc[h2_c][1]
    start_n = hdn[h1_n][0]
    end_n = hdn[h2_n][1]
    if (end_n - start_n) != (end_c - start_c):
        #print(end_n - start_n)
        #print(end_c - start_c)
        if keep == "n":
            start_c = end_c - (end_n - start_n)
        elif keep == "c":
            end_n = start_n + (end_c - start_c) 
        else:
            print("keep must be n or c")
        while (start_c < 1) or (start_n < 1):
            start_c +=1
            start_n +=1
    range_CA_align(copy_c, pose_n, start_c, end_c, start_n, end_n)
    if keep == "n":
        cut1 = end_n 
        cut2 = end_c         
    elif keep == "c":
        cut1 = start_n 
        cut2 = start_c 
    else:
        print("keep must be n or c")
    #print(cut1,cut2)
    for i in range(1,cut1):
        newpose.append_residue_by_bond(pose_n.residue(i))
    for i in range(cut2,len(pose_c.sequence())+1):
        newpose.append_residue_by_bond(copy_c.residue(i))
    offset = (len(newpose.sequence())-len(pose_c.sequence()))    
    
    selx = pyrosetta.rosetta.core.select.residue_selector.ResiduePDBInfoHasLabelSelector("IntX")
    sely = pyrosetta.rosetta.core.select.residue_selector.ResiduePDBInfoHasLabelSelector("IntY")
    int_n = pyrosetta.rosetta.core.select.residue_selector.OrResidueSelector(selx,sely).apply(pose_n)
    int_c = pyrosetta.rosetta.core.select.residue_selector.OrResidueSelector(selx,sely).apply(pose_c)
    for i in pyrosetta.rosetta.core.select.get_residues_from_subset(int_n):
        newpose.replace_residue(i,pose_n.residue(i),1)
    for i in pyrosetta.rosetta.core.select.get_residues_from_subset(int_c):
        newpose.replace_residue(i+offset,pose_c.residue(i),1)
    info = pyrosetta.rosetta.core.pose.PDBInfo(newpose,1)
    for label in ["IntX","IntY"]:
        sel = pyrosetta.rosetta.core.select.residue_selector.ResiduePDBInfoHasLabelSelector(label)
        int_n = sel.apply(pose_n)
        int_c = sel.apply(pose_c)
        for i in pyrosetta.rosetta.core.select.get_residues_from_subset(int_n):            
            info.add_reslabel(i,label)
        for i in pyrosetta.rosetta.core.select.get_residues_from_subset(int_c):            
            info.add_reslabel(i+offset,label)
        newpose.pdb_info(info)
    return newpose
    
    
def oligomer_align(oligomer,monomer,const_term = "n", mono_chains = [1]):
    oligo = load_pose(oligomer)
    mono_full = load_pose(monomer)
    if mono_chains == [1]:
        mono = mono_full
    else:
        mono = pyrosetta.rosetta.core.pose.Pose()
        for i in mono_chains:
            pyrosetta.rosetta.core.pose.append_pose_to_pose(mono,mono_full.split_by_chain(i),1)
    if const_term in ["n","N"]:
        start_m = 1
        end_m = len(oligo.chain_sequence(1))
    elif const_term in ["c","C"]:
        start_m = mono.size() - len(oligo.chain_sequence(1)) + 1
        end_m = mono.size()
    else:
        print("const_term must be n or c")
    newpose = pyrosetta.rosetta.core.pose.Pose()
    for i in range(oligo.num_chains()):
        start_o = 1 + (i * len(oligo.chain_sequence(1)))
        end_o = ((i+1) * len(oligo.chain_sequence(1)))
        range_CA_align(mono, oligo, start_m, end_m, start_o, end_o)
        if i == 0:
            newpose = mono.clone()
        if i >= 1:
            for j in range(1,mono.num_chains()+1):
                pyrosetta.rosetta.core.pose.append_pose_to_pose(newpose,mono.split_by_chain(j),1)
        
    return newpose

def swap_chains(name,order):
    pose_in = load_pose(name)
    pose_out = pyrosetta.rosetta.core.pose.Pose()
    for i in order:
        pyrosetta.rosetta.core.pose.append_pose_to_pose(pose_out,pose_in.split_by_chain(i),1)
    return pose_out


def extend_oligomer(oligomer,extension,term,keep,oligo_hlx1,oligo_hlx2,ext_hlx1,ext_hlx2):
    oligo = load_pose(oligomer)
    ext = load_pose(extension)
    oligo_sym = oligo.num_chains()
    ext_chains = range(1,ext.num_chains()+1)
    if term in ['N','n']:
        p1 = extend_dhr(extension,oligomer,keep,ext_hlx1,ext_hlx2,oligo_hlx1,oligo_hlx2)
        p2 = oligomer_align(oligomer,p1,"c",ext_chains)
    elif term in ['C','c']:
        p1 = extend_dhr(oligomer,extension,keep,oligo_hlx1,oligo_hlx2,ext_hlx1,ext_hlx2)
        p2 = oligomer_align(oligomer,p1,"n",[x-1+oligo_sym for x in ext_chains])
    else:
        print("term must be n or c")
    return p2

def extend_oligo_hinge(hinge,parent,nrep=2,crep=2):
    par = load_pose(parent).split_by_chain(1)
    hin = load_pose(hinge)
    nres = []
    cres = []
    offset = hin.split_by_chain(1).size() - par.size()
    for i in range(1,par.size()//2 - 10):
        if par.sequence(i,i) != hin.sequence(i,i):
            nres.append(i)
    for i in range(par.size()//2 + 10,par.size()):
        if par.sequence(i,i) != hin.sequence(i+offset,i+offset):
            cres.append(i)        
    print(nres)
    print(cres)
    p1 = extend_dhr(par,hin.split_by_chain(1),"n",5,6,1,2)
    offset_n = p1.split_by_chain(1).size() - hin.split_by_chain(1).size()
    print(offset_n,offset)
    p2 = oligomer_align(hin,p1,const_term = "c")
    p3 = extend_dhr(p2.split_by_chain(1),par,"c","last","last",3,4)
    offset_c = p3.split_by_chain(1).size() - p1.split_by_chain(1).size()
    for i in nres:
        p3.replace_residue(i+offset_n,hin.residue(i),1)
    for i in cres:
        p3.replace_residue(i+offset_n+offset,hin.residue(i+offset),1)
    p4 = oligomer_align(p2,p3,const_term = "n")
    return p4

def extend_mono_hinge(hinge,parent,nrep=2,crep=2):
    par = load_pose(parent).split_by_chain(1)
    hin = load_pose(hinge)
    nres = []
    cres = []
    offset = hin.split_by_chain(1).size() - par.size()
    for i in range(1,par.size()//2 - 10):
        if par.sequence(i,i) != hin.sequence(i,i):
            nres.append(i)
    for i in range(par.size()//2 + 10,par.size()):
        if par.sequence(i,i) != hin.sequence(i+offset,i+offset):
            cres.append(i)        
    print(nres)
    print(cres)
    if nrep ==2:
        p1 = extend_dhr(par,hin.split_by_chain(1),"c",7,8,3,4)
    elif nrep ==1: 
        p1 = extend_dhr(par,hin.split_by_chain(1),"c",5,6,3,4)
    offset_n = p1.split_by_chain(1).size() - hin.split_by_chain(1).size()
    print(offset_n,offset)
    p2 = p1
    if crep == 2:
        p3 = extend_dhr(p2.split_by_chain(1),par,"c","last","last",3,4)
    elif crep == 1:
        p3 = extend_dhr(p2.split_by_chain(1),par,"c","last","last",5,6)
    offset_c = p3.split_by_chain(1).size() - p1.split_by_chain(1).size()
    for i in nres:
        p3.replace_residue(i+offset_n,hin.residue(i),1)
    for i in cres:
        p3.replace_residue(i+offset_n+offset,hin.residue(i+offset),1)
    p4 = p3
    return p4

# %%
p = extend_mono_hinge("in/cs_221X.pdb","in/DHR20.pdb",1,1)
p.dump_pdb("cs221_X_n1c1.pdb")
p = extend_mono_hinge("in/cs_221Y.pdb","in/DHR20.pdb",1,1)
p.dump_pdb("cs221_Y_n1c1.pdb")
p = extend_mono_hinge("in/cs_221X.pdb","in/DHR20.pdb")
p.dump_pdb("cs221_X_n2c2.pdb")
p = extend_mono_hinge("in/cs_221Y.pdb","in/DHR20.pdb")
p.dump_pdb("cs221_Y_n2c2.pdb")

# %%
p = extend_dhr('in/DHR14a.pdb','in/J7X_G133P.pdb',"n", 3,4,1,2)
p.dump_pdb('J7X_P_extn1.pdb')
p = extend_dhr('in/DHR14a.pdb','in/J7Y_G133P.pdb',"n", 3,4,1,2)
p.dump_pdb('J7Y_P_extn1.pdb')

# %%
p = extend_dhr('in/DHR14a.pdb','in/J7X_G133P.pdb',"n", 5,6,1,2)
p.dump_pdb('J7X_P_extn2.pdb')
p = extend_dhr('in/DHR14a.pdb','in/J7Y_G133P.pdb',"n", 5,6,1,2)
p.dump_pdb('J7Y_P_extn2.pdb')

# %%
p = extend_dhr('in/DHR14b.pdb','in/J7X_G133P.pdb',"n", 3,4,1,2)
p.dump_pdb('J7X_P_extn1_dhr14x.pdb')
p = extend_dhr('in/DHR14b.pdb','in/J7Y_G133P.pdb',"n", 3,4,1,2)
p.dump_pdb('J7Y_P_extn1_dhr14x.pdb')
p = extend_dhr('in/DHR14b.pdb','in/J7X_G133P.pdb',"n", 5,6,1,2)
p.dump_pdb('J7X_P_extn2_dhr14x.pdb')
p = extend_dhr('in/DHR14b.pdb','in/J7Y_G133P.pdb',"n", 5,6,1,2)
p.dump_pdb('J7Y_P_extn2_dhr14x.pdb')

# %%
p = extend_mono_hinge("in/cs201r1_X.pdb","in/DHR82.pdb",1,1)
p.dump_pdb("cs201_X_n1c1.pdb")
p = extend_mono_hinge("in/cs201r1_Y.pdb","in/DHR82.pdb",1,1)
p.dump_pdb("cs201_Y_n1c1.pdb")
p = extend_mono_hinge("in/cs201r1_X.pdb","in/DHR82.pdb")
p.dump_pdb("cs201_X_n2c2.pdb")
p = extend_mono_hinge("in/cs201r1_Y.pdb","in/DHR82.pdb")
p.dump_pdb("cs201_Y_n2c2.pdb")

# %%
p = extend_mono_hinge("in/pair157_232_Y_0001.pdb","in/DHR82.pdb")
p.dump_pdb("FF74_Y_n2c2_new_unrel.pdb")

# %%
p = extend_mono_hinge("in/pair157_232_X_0001.pdb","in/DHR82.pdb",1,1)
p.dump_pdb("FF74_X_n1c1.pdb")
p = extend_mono_hinge("in/pair157_232_Y_0001.pdb","in/DHR82.pdb",1,1)
p.dump_pdb("FF74_Y_n1c1.pdb")

# %%
p = extend_hinge("in/FF86-0.pdb","in/DHR21.pdb")
p.dump_pdb("v3_FF86-0_n2c2.pdb")
p = extend_hinge("in/FF86-1.pdb","in/DHR21.pdb")
p.dump_pdb("v3_FF86-1_n2c2.pdb")
p = extend_hinge("in/FF86-2.pdb","in/DHR21.pdb")
p.dump_pdb("v3_FF86-2_n2c2.pdb")

# %%
p = extend_oligo_hinge("in/FF81-0.pdb","in/DHR46.pdb")
p.dump_pdb("v3_FF81-0_n2c2.pdb")
p = extend_oligo_hinge("in/FF81-1.pdb","in/DHR46.pdb")
p.dump_pdb("v3_FF81-1_n2c2.pdb")

# %%
helix_dict(load_pose("in/pair157_232_X_0001.pdb"))

# %%
helix_dict(load_pose("/projects/crispy_shifty/data/pdbs/DHR20.pdb"))[1]

# %%
hd = helix_dict(load_pose("in/DHR46.pdb"))
for i in list(hd):
    print(hd[i][1]-hd[i][0])

# %%
hd = helix_dict(load_pose("in/FF81-1.pdb"))
for i in list(hd):
    print(hd[i][1]-hd[i][0])

# %%
pyrosetta.rosetta.protocols.protein_interface_design.FavorNativeResidue?

# %%
p = extend_oligo_hinge("in/FF81-0.pdb","in/DHR46.pdb")

# %%
res = p.residue(4)

# %%
res.
