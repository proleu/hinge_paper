# %% [markdown]
# # Run hacked AlphaFold2 on the designed paired state Y's

# %% [markdown]
# ### Imports

# %%
# %load_ext lab_black
# Python standard library
from glob import glob
import os
import socket
import sys

# 3rd party library imports
import dask
import matplotlib.pyplot as plt
import pandas as pd
import pyrosetta
import numpy as np
import scipy
import seaborn as sns
from tqdm.auto import tqdm  # jupyter compatible progress bar

tqdm.pandas()  # link tqdm to pandas
# Notebook magic
# save plots in the notebook
# %matplotlib inline
# reloads modules automatically before executing cells
# %load_ext autoreload
# %autoreload 2
print(f"running in directory: {os.getcwd()}")  # where are we?
print(f"running on node: {socket.gethostname()}")  # what node are we on?
# Out:
# running in directory: /mnt/projects/crispy_shifty/projects/crispy_shifties
# running on node: dig95

# %% [markdown]
# ### Set working directory to the root of the crispy_shifty repo
# Note: We want to use perlmutter

# %%
os.chdir("/global/cfs/cdirs/m4129/projects/crispy_shifty")

# %% [markdown]
# ### Fix the paths
# Necessary because we are on perlmutter

# %%
from crispy_shifty.utils.io import fix_path_prefixes

pairs = os.path.join(
    os.getcwd(),
    "projects/crispy_shifties/06_mpnn_paired_states/mpnn_paired_states.pair",
)
new_pairs = fix_path_prefixes(
    find="/mnt",
    replace="/global/cfs/cdirs/m4129",
    file=pairs,
    overwrite=True,
)
best_pairs = os.path.join(
    os.getcwd(),
    "projects/crispy_shifties/06_mpnn_paired_states_best/best_mpnn_paired_states.pair",
)
new_pairs = fix_path_prefixes(
    find="/mnt",
    replace="/global/cfs/cdirs/m4129",
    file=best_pairs,
    overwrite=True,
)
# Out:
# /global/cfs/cdirs/m4129/projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %% [markdown]
# ### Run AF2 on the designed paired states Y's

# %%
from crispy_shifty.utils.io import gen_array_tasks

simulation_name = "07_fold_paired_states_Y"
design_list_file = os.path.join(
    os.getcwd(),
    "projects/crispy_shifties/06_mpnn_paired_states/mpnn_paired_states.pair",
)
output_path = os.path.join(f"/pscratch/sd/p/pleung/{simulation_name}")

options = " ".join(
    [
        "out:level 200",
    ]
)
extra_kwargs = {"models": "1"}

gen_array_tasks(
    distribute_func="crispy_shifty.protocols.folding.fold_paired_state_Y",
    design_list_file=design_list_file,
    output_path=output_path,
    perlmutter_mode=True,
    nstruct=1,
    nstruct_per_task=1,
    options=options,
    extra_kwargs=extra_kwargs,
    simulation_name=simulation_name,
    time="27:30",
)
# Out:
# Run the following command with your desired environment active:
# sbatch -a 1-5533 /pscratch/sd/p/pleung/07_fold_paired_states_Y/run.sh

# %% [markdown]
# ### Run AF2 on the best designed paired states Y's

# %%
from crispy_shifty.utils.io import gen_array_tasks

simulation_name = "07_fold_paired_states_Y_best"
design_list_file = os.path.join(
    os.getcwd(),
    "projects/crispy_shifties/06_mpnn_paired_states_best/best_mpnn_paired_states.pair",
)
output_path = os.path.join(f"/pscratch/sd/p/pleung/{simulation_name}")

options = " ".join(
    [
        "out:level 200",
    ]
)
extra_kwargs = {"models": "1"}

gen_array_tasks(
    distribute_func="crispy_shifty.protocols.folding.fold_paired_state_Y",
    design_list_file=design_list_file,
    output_path=output_path,
    perlmutter_mode=True,
    nstruct=1,
    nstruct_per_task=1,
    options=options,
    extra_kwargs=extra_kwargs,
    simulation_name=simulation_name,
    time="27:30",
)

# %% [markdown]
# ### Set working directory to the root of the crispy_shifty repo
# Note: We rsync the perlmutter results, now back on the digs

# %%
os.chdir("/projects/crispy_shifty")

# %% [markdown]
# ### Collect scorefiles of the folded paired state Ys and concatenate

# %%
sys.path.insert(0, "/projects/crispy_shifty")
from crispy_shifty.utils.io import collect_score_file

simulation_name = "07_fold_paired_states_Y"
output_path = os.path.join(os.getcwd(), f"projects/crispy_shifties/{simulation_name}")

if not os.path.exists(os.path.join(output_path, "scores.json")):
    collect_score_file(output_path, "scores")
# Out:
# /projects/crispy_shifty/envs/crispy/lib/python3.8/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %% [markdown]
# ### Load resulting concatenated scorefile

# %%
sys.path.insert(0, "/projects/crispy_shifty")
from crispy_shifty.utils.io import parse_scorefile_linear

output_path = os.path.join(os.getcwd(), f"projects/crispy_shifties/{simulation_name}")

if not os.path.exists(os.path.join(output_path, "scores.csv")):
    scores_df = parse_scorefile_linear(os.path.join(output_path, "scores.json"))
# Out:
#   0%|          | 0/71831 [00:00<?, ?it/s]

# %% [markdown]
# ### Dump scores_df as a CSV and then reload, for performance reasons

# %%
if not os.path.exists(os.path.join(output_path, "scores.csv")):
    scores_df.to_csv(os.path.join(output_path, "scores.csv"))

scores_df = pd.read_csv(os.path.join(output_path, "scores.csv"), index_col="Unnamed: 0")

# %% [markdown]
# ### Collect scorefiles of the best folded paired state Ys and concatenate

# %%
sys.path.insert(0, "/projects/crispy_shifty")
from crispy_shifty.utils.io import collect_score_file

simulation_name = "07_fold_paired_states_Y_best"
output_path = os.path.join(os.getcwd(), f"projects/crispy_shifties/{simulation_name}")

if not os.path.exists(os.path.join(output_path, "scores.json")):
    collect_score_file(output_path, "scores")

# %% [markdown]
# ### Load resulting concatenated scorefile

# %%
sys.path.insert(0, "/projects/crispy_shifty")
from crispy_shifty.utils.io import parse_scorefile_linear

output_path = os.path.join(os.getcwd(), f"projects/crispy_shifties/{simulation_name}")

if not os.path.exists(os.path.join(output_path, "scores.csv")):
    scores_df = parse_scorefile_linear(os.path.join(output_path, "scores.json"))
# Out:
#   0%|          | 0/47746 [00:00<?, ?it/s]

# %% [markdown]
# ### Dump scores_df as a CSV and then reload, for performance reasons

# %%
if not os.path.exists(os.path.join(output_path, "scores.csv")):
    scores_df.to_csv(os.path.join(output_path, "scores.csv"))

scores_df = pd.read_csv(os.path.join(output_path, "scores.csv"), index_col="Unnamed: 0")

# %% [markdown]
# ### Check that both scorefiles have the same columns, then concatenate them

# %%
others = pd.read_csv(
    os.path.join(
        os.getcwd(), "projects/crispy_shifties/07_fold_paired_states_Y/scores.csv"
    ),
    index_col="Unnamed: 0",
)
best = pd.read_csv(
    os.path.join(
        os.getcwd(), "projects/crispy_shifties/07_fold_paired_states_Y_best/scores.csv"
    ),
    index_col="Unnamed: 0",
)
assert len(set(others.columns) - set(best.columns)) == 0
scores_df = pd.concat([best, others])

# %%
scores_df.head()
# Out:
#                                                     Y_mean_pae  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...    3.952967
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...    3.374745
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...    3.814826
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...    3.825995
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...    4.072604
#
#                                                     Y_mean_pae_interaction  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                4.652984
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                3.794436
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                4.597098
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                4.258829
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                4.852204
#
#                                                     Y_mean_pae_interaction_AB  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                   4.197033
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                   3.557037
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                   4.003360
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                   3.895220
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                   4.259923
#
#                                                     Y_mean_pae_interaction_BA  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                   5.108934
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                   4.031836
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                   5.190837
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                   4.622437
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                   5.444485
#
#                                                     Y_mean_pae_intra_chain  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                3.142503
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                2.862908
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                3.202939
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                3.436471
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                3.186945
#
#                                                     Y_mean_pae_intra_chain_A  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                  3.749430
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                  3.181711
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                  3.497121
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                  3.571807
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                  3.798563
#
#                                                     Y_mean_pae_intra_chain_B  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                  2.535577
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                  2.544106
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                  2.908757
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                  3.301136
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...                  2.575327
#
#                                                     Y_mean_plddt  Y_model  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...     93.147110        1
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...     95.446846        1
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...     93.410522        1
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...     92.548485        1
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...     93.173622        1
#
#                                                     Y_pTMscore  ...  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...    0.868070  ...
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...    0.903480  ...
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...    0.879998  ...
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...    0.881482  ...
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...    0.855877  ...
#
#                                                                               state  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...   X22_3_16_4_ct4_fa_p_5_s_-3_d_6
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...    X22_3_17_4_ct1_fe_p_4_s_1_d_3
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  X17_4_20_3_ct10_fb_p_4_s_-3_d_5
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...               DHR24_p_5_s_-3_d_6
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...   X22_3_16_4_ct4_fa_p_5_s_-3_d_6
#
#                                                            time       tol  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  2924.451803  0.107800
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  5314.051886  0.120277
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  2775.576774  0.208264
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  3617.167408  0.750120
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  3012.936898  0.151971
#
#                                                         topo total_length  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  HHHHHHHH        206.0
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  HHHHHHHH        217.0
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  HHHHHHHH        207.0
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  HHHHHHHH        215.0
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  HHHHHHHH        206.0
#
#                                                     total_score  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...   859.011150
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  1212.198097
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...   110.707965
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...   785.697384
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...   -44.907417
#
#                                                     trimmed_length  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...             177
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...             181
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...             175
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...             182
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...             177
#
#                                                            type  wnm_all_x  \
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  monomer_ptm   0.757027
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  monomer_ptm   0.994143
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  monomer_ptm   0.705978
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  monomer_ptm   0.802904
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...  monomer_ptm   0.623417
#
#                                                     yhh_planarity
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...   7.726905e-08
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...   3.595795e-07
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...   0.000000e+00
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...   0.000000e+00
# /pscratch/sd/p/pleung/07_fold_paired_states_Y_b...   4.858594e-08
#
# [5 rows x 119 columns]

# %% [markdown]
# ### Setup for plotting

# %%
sns.set(
    context="talk",
    font_scale=1,  # make the font larger; default is pretty small
    style="ticks",  # make the background white with black lines
    palette="colorblind",  # a color palette that is colorblind friendly!
)

# %% [markdown]
# ### Data exploration
# Gonna remove the Rosetta sfxn scoreterms for now

# %%
rosetta = scores_df[scores_df["designed_by"] == "rosetta"]
mpnn = scores_df[scores_df["designed_by"] == "mpnn"].sample(1000, random_state=0)
sample_df = pd.concat([rosetta, mpnn])

# %% [markdown]
# ### Remove score terms we don't care about

# %%
from crispy_shifty.protocols.design import beta_nov16_terms

sample_df = sample_df[
    [term for term in sample_df.columns if term not in beta_nov16_terms]
]
print(len(sample_df))
print(list(sample_df.columns))
# Out:
# 2396
# ['Y_mean_pae', 'Y_mean_pae_interaction', 'Y_mean_pae_interaction_AB', 'Y_mean_pae_interaction_BA', 'Y_mean_pae_intra_chain', 'Y_mean_pae_intra_chain_A', 'Y_mean_pae_intra_chain_B', 'Y_mean_plddt', 'Y_model', 'Y_pTMscore', 'Y_recycles', 'Y_rmsd_to_reference', 'Y_seed', 'Y_tol', 'Y_type', 'bb_clash', 'bb_clash_delta', 'bb_clash_delta_x', 'best_average_DAN_plddts', 'best_average_plddts', 'best_model', 'best_ptm', 'best_rmsd_to_input', 'buns_parent', 'cms_AcB', 'cms_AnAc', 'cms_AnAcB', 'cms_AnB', 'designed_by', 'docked_helix', 'dssp', 'elapsed_time', 'exposed_hydrophobics_parent', 'geometry_parent', 'holes_all_parent', 'holes_core_parent', 'interface', 'loop_dist', 'loop_sc', 'looped_length', 'mean_pae', 'mean_pae_interaction', 'mean_pae_interaction_AB', 'mean_pae_interaction_BA', 'mean_pae_intra_chain', 'mean_pae_intra_chain_A', 'mean_pae_intra_chain_B', 'mean_plddt', 'mismatch_probability_parent', 'model', 'mpnn_design_area', 'mpnn_msd_design_area', 'mpnn_msd_temperature', 'mpnn_temperature', 'new_loop_str', 'pTMscore', 'packstat_parent', 'parent', 'parent_length', 'path_in', 'pdb', 'pivot_helix', 'pre_break_helix', 'recycles', 'rmsd_to_reference', 'sap_parent', 'sc_AcB', 'sc_AnAc', 'sc_AnAcB', 'sc_AnB', 'sc_all_parent', 'scaffold_type', 'score', 'score_per_res', 'score_per_res_parent', 'score_per_res_x', 'seed', 'shift', 'ss_sc', 'state', 'time', 'tol', 'topo', 'total_length', 'total_score', 'trimmed_length', 'type', 'wnm_all_x']

# %%
from crispy_shifty.utils.plotting import histplot_df, pairplot_df

to_plot = [
    "best_average_plddts",
    "best_model",
    "best_ptm",
    "best_rmsd_to_input",
    "cms_AcB",
    "cms_AnAc",
    "cms_AnAcB",
    "cms_AnB",
    "designed_by",
    "interface",
    "mean_pae",
    "mean_pae_interaction",
    "mean_pae_interaction_AB",
    "mean_pae_interaction_BA",
    "mean_pae_intra_chain",
    "mean_pae_intra_chain_A",
    "mean_pae_intra_chain_B",
    "mean_plddt",
    "mismatch_probability_parent",
    "pTMscore",
    "packstat_parent",
    "pdb",
    "recycles",
    "rmsd_to_reference",
    "sap_parent",
    "sc_AcB",
    "sc_AnAc",
    "sc_AnAcB",
    "sc_AnB",
    "sc_all_parent",
    "score_per_res",
    "score_per_res_parent",
    "ss_sc",
    "state",
    "topo",
]
print(to_plot)
# Out:
# ['best_average_plddts', 'best_model', 'best_ptm', 'best_rmsd_to_input', 'cms_AcB', 'cms_AnAc', 'cms_AnAcB', 'cms_AnB', 'designed_by', 'interface', 'mean_pae', 'mean_pae_interaction', 'mean_pae_interaction_AB', 'mean_pae_interaction_BA', 'mean_pae_intra_chain', 'mean_pae_intra_chain_A', 'mean_pae_intra_chain_B', 'mean_plddt', 'mismatch_probability_parent', 'pTMscore', 'packstat_parent', 'pdb', 'recycles', 'rmsd_to_reference', 'sap_parent', 'sc_AcB', 'sc_AnAc', 'sc_AnAcB', 'sc_AnB', 'sc_all_parent', 'score_per_res', 'score_per_res_parent', 'ss_sc', 'state', 'topo']

# %% [markdown]
# ### Plot before and after multistate design AF2 metrics

# %%
cols = [
    "best_average_plddts",
    "best_ptm",
    "best_rmsd_to_input",
    "mean_plddt",
    "pTMscore",
    "rmsd_to_reference",
]
the_fig = histplot_df(
    df=sample_df,
    cols=cols,
    bins=10,
    hue="designed_by",
)
plt.savefig(os.path.join(output_path, "old_vs_new_af2_scores.png"))
# Out:
# 6it [00:00, 18.01it/s]

# %%
the_fig = pairplot_df(
    df=sample_df,
    cols=cols,
    hue="designed_by",
)
plt.savefig(os.path.join(output_path, "old_vs_new_af2_scores_paired.png"))

# %%
# the_fig = histplot_df(
#     df=sample_df,
#     cols=cols,
#     bins=10,
#     hue="interface",
# )

# %%
# the_fig = pairplot_df(
#     df=sample_df,
#     cols=cols,
#     hue="interface",
# )

# %% [markdown]
# ### Plot effects of MPNN temperature and selector areas on AF2 metrics

# %%
# mpnn["mpnn_temperature"] = mpnn["mpnn_temperature"].astype(str)

# cols = [
#     "best_average_plddts",
#     "best_ptm",
#     "best_rmsd_to_input",
#     "mean_plddt",
#     "pTMscore",
#     "rmsd_to_reference",
# ]
# the_fig = histplot_df(
#     df=mpnn,
#     cols=cols,
#     bins=10,
#     hue="mpnn_temperature",
# )

# %%
# the_fig = pairplot_df(
#     df=mpnn,
#     cols=cols,
#     hue="mpnn_temperature",
# )

# %%
mpnn["mpnn_msd_temperature"] = mpnn["mpnn_msd_temperature"].astype(str)

cols = [
    "best_average_plddts",
    "best_ptm",
    "best_rmsd_to_input",
    "mean_plddt",
    "pTMscore",
    "rmsd_to_reference",
]
the_fig = histplot_df(
    df=mpnn,
    cols=cols,
    bins=10,
    hue="mpnn_msd_temperature",
)
plt.savefig(os.path.join(output_path, "old_vs_new_af2_scores_temp.png"))
# Out:
# 6it [00:00, 26.27it/s]

# %%
the_fig = pairplot_df(
    df=mpnn,
    cols=cols,
    hue="mpnn_msd_temperature",
)
plt.savefig(os.path.join(output_path, "old_vs_new_af2_scores_temp_paired.png"))

# %%
the_fig = histplot_df(
    df=mpnn,
    cols=cols,
    bins=10,
    hue="mpnn_msd_design_area",
)
plt.savefig(os.path.join(output_path, "old_vs_new_af2_scores_area.png"))
# Out:
# 6it [00:00, 15.31it/s]

# %%
the_fig = pairplot_df(
    df=mpnn,
    cols=cols,
    hue="mpnn_msd_design_area",
)
plt.savefig(os.path.join(output_path, "old_vs_new_af2_scores_area_paired.png"))

# %%
# sample_df["best_model"] = sample_df["best_model"].astype(str)
# the_fig = histplot_df(
#     df=sample_df,
#     cols=cols,
#     bins=10,
#     hue="best_model",
# )

# %%
# sample_df["best_model"] = sample_df["best_model"].astype(str)
# the_fig = histplot_df(
#     df=sample_df,
#     cols=cols,
#     bins=10,
#     hue="topo",
# )

# %% [markdown]
# ### Plot interface metrics

# %%
cols = [
    "cms_AnAcB",
    "mean_pae",
    "mean_pae_interaction",
    "mean_pae_intra_chain",
    "mean_plddt",
    "sc_AnAcB",
]
the_fig = histplot_df(
    df=sample_df,
    cols=cols,
    bins=10,
    hue="designed_by",
)
plt.savefig(os.path.join(output_path, "interface_scores.png"))
# Out:
# 6it [00:00, 18.20it/s]

# %%
the_fig = pairplot_df(
    df=sample_df,
    cols=cols,
    hue="designed_by",
)
plt.savefig(os.path.join(output_path, "interface_scores_paired.png"))

# %%
# the_fig = histplot_df(
#     df=sample_df,
#     cols=cols,
#     bins=10,
#     hue="interface",
# )

# %%
# the_fig = pairplot_df(
#     df=sample_df,
#     cols=cols,
#     hue="interface",
# )

# %% [markdown]
# ### Plot effects of MPNN temperature and selector areas on interface metrics

# %%
cols = [
    "cms_AnAcB",
    "mean_pae",
    "mean_pae_interaction",
    "mean_pae_intra_chain",
    "mean_plddt",
    "sc_AnAcB",
]
the_fig = histplot_df(
    df=mpnn,
    cols=cols,
    bins=10,
    hue="mpnn_msd_temperature",
)
plt.savefig(os.path.join(output_path, "interface_scores_temp.png"))
# Out:
# 6it [00:00, 11.66it/s]

# %%
the_fig = pairplot_df(
    df=mpnn,
    cols=cols,
    hue="mpnn_msd_temperature",
)
plt.savefig(os.path.join(output_path, "interface_scores_temp_paired.png"))

# %%
the_fig = histplot_df(
    df=mpnn,
    cols=cols,
    bins=10,
    hue="mpnn_msd_design_area",
)
plt.savefig(os.path.join(output_path, "interface_scores_area.png"))
# Out:
# 6it [00:00, 15.52it/s]

# %%
the_fig = pairplot_df(
    df=mpnn,
    cols=cols,
    hue="mpnn_msd_design_area",
)
plt.savefig(os.path.join(output_path, "interface_scores_area_paired.png"))

# %% [markdown]
# ### Filter the whole df

# %%
query = "mean_plddt > 93"

filtered = scores_df.query(query)
len(filtered)
# Out:
# 107311

# %%
print(list(sorted(set([v for v in filtered.parent.values if len(v) == 5]))))
print(len([v for v in filtered.designed_by.values if v == "rosetta"]))
# Out:
# ['DHR14', 'DHR20', 'DHR21', 'DHR24', 'DHR26', 'DHR27', 'DHR32', 'DHR36', 'DHR39', 'DHR46', 'DHR47', 'DHR49', 'DHR52', 'DHR54', 'DHR59', 'DHR62', 'DHR64', 'DHR68', 'DHR70', 'DHR71', 'DHR72', 'DHR76', 'DHR79', 'DHR80', 'DHR81', 'DHR82']
# 1155

# %% [markdown]
# ### Plot topo and scaffold_type fraction before and after

# %%
(
    fig,
    (ax1, ax2),
) = plt.subplots(ncols=2, figsize=(20, 10), tight_layout=True)
scores_df.groupby("scaffold_type").size().plot(kind="pie", autopct="%1.2f%%", ax=ax1)
ax1.set_ylabel("before", rotation=0)
filtered.groupby("scaffold_type").size().plot(kind="pie", autopct="%1.2f%%", ax=ax2)
ax2.set_ylabel("after", rotation=0)

plt.savefig(os.path.join(output_path, "filtering_effect_scaffold_type.png"))

# %% [markdown]
# ### Sort the filtered df by length

# %%
filtered = filtered.sort_values("looped_length")

# %% [markdown]
# ### Save a list of outputs
# Sort by length

# %%
simulation_name = "07_fold_paired_states_Y"
output_path = os.path.join(os.getcwd(), f"projects/crispy_shifties/{simulation_name}")

with open(os.path.join(output_path, "folded_paired_states.list"), "w") as f:
    for path in tqdm(filtered.index):
        print(path, file=f)
# Out:
#   0%|          | 0/107311 [00:00<?, ?it/s]

# %% [markdown]
# ### Save a list of chunked outputs
# 50 per chunk

# %%
from more_itertools import ichunked

with open(os.path.join(output_path, "folded_paired_states.pair"), "w") as f:
    for paths in ichunked(tqdm(filtered.index), 50):
        line = "____".join(paths)
        print(line, file=f)
# Out:
#   0%|          | 0/107311 [00:00<?, ?it/s]

# %% [markdown]
# ### Prototyping blocks

# %% [markdown]
# test `fold_paired_state_Y`

# %%
# %%time 
from operator import gt, lt
import pyrosetta

filter_dict = {
    "mean_plddt": (gt, 85.0),
    "rmsd_to_reference": (lt, 2.2),
    "mean_pae_interaction": (lt, 10.0),
}

pyrosetta.init()


sys.path.insert(0, "~/projects/crispy_shifty/") # TODO projects
from crispy_shifty.protocols.folding import fold_paired_state_Y

t = fold_paired_state_Y(
        None,
        **{
#             'fasta_path': 'TODO',
            "filter_dict": filter_dict,
            "models": [1], # TODO
            'pdb_path': '/mnt/home/pleung/projects/crispy_shifty/projects/crispy_shifties/06_mpnn_paired_states/decoys/0000/06_mpnn_paired_states_e6c08d9247294efbb7f84c704711447b.pdb.bz2____/mnt/home/pleung/projects/crispy_shifty/projects/crispy_shifties/06_mpnn_paired_states/fastas/0000/06_mpnn_paired_states_e6c08d9247294efbb7f84c704711447b.fa',
#             'fasta_path': 'bar.fa',
#             "models": [1, 2], # TODO
#             'pdb_path': 'foo.pdb.bz2',
            
        }
)
for i, tppose in enumerate(t):
    tppose.pose.dump_pdb(f"{i}.pdb")

# %%
tppose.pose.scores
